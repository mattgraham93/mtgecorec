# %% [markdown]
# # MTG Card Scoring Algorithm - Critical Fixes Validation
#
# **Date:** January 23, 2026
# **Purpose:** Validate fixes for:
# 1. Color identity enforcement (strict Commander format rules)
# 2. Mechanic synergy calculation (debug always-100 issue)
# 3. Card deduplication (remove duplicate cards from results)
#
# ## Critical Validation Checklist
#
# - [ ] Color identity enforcement working (illegal cards get multiplier = 0.0)
# - [ ] No off-color cards in top 100 recommendations
# - [ ] Synergy scores have meaningful variance (not all 100)
# - [ ] No duplicate card names in results
# - [ ] Different commanders get different recommendations

# %% [markdown]
# ## Section 1: Load Data and Initialize Scorer
#
# Load the cards dataset and initialize CardScorer with color identity lookup from CosmosDB.

# %%
import pandas as pd
import numpy as np
import sys
import logging

# Setup logging to see diagnostic messages
logging.basicConfig(
    level=logging.DEBUG,
    format='%(levelname)s: %(message)s'
)

# Add project to path
sys.path.insert(0, '/workspaces/mtgecorec')

from core.data_engine.card_scoring import CardScorer

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
# Initialize CardScorer
print("Initializing CardScorer...")
scorer = CardScorer(data_path='/workspaces/mtgecorec/notebooks/')

print(f"✓ CardScorer initialized")
print(f"  - Total cards loaded: {len(scorer.all_cards)}")
print(f"  - Color identity lookup entries: {len(scorer.color_identity_lookup)}")
print(f"  - Mechanic weights loaded: {len(scorer.mechanic_weight_lookup)}")

# DEBUG: Show what's actually in the lookup
if len(scorer.color_identity_lookup) > 0:
    sample_items = list(scorer.color_identity_lookup.items())[:3]
    print(f"\n  Sample color identity data:")
    for card_name, colors in sample_items:
        print(f"    {card_name}: {colors}")
else:
    print(f"\n  ⚠ WARNING: Color identity lookup is EMPTY!")
    print(f"    This means CosmosDB load failed or returned no data")
# Out:
# INFO: Initializing CardScorer from /workspaces/mtgecorec/notebooks/
# INFO: Loaded 73063 cards from master_analysis_full.csv
# INFO: Loaded 50 mechanic weights
# INFO: Loaded 700 archetype-mechanic mappings
# INFO: Loaded 12061 combo cards
# Initializing CardScorer...
# INFO: Loaded mechanic co-occurrence matrix
# INFO: Loading color identity from CosmosDB cards collection...
# INFO: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
# DEBUG: {"message": "Starting topology monitoring", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "previousDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# DEBUG: {"message": "Starting server monitoring", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Server selection started", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}}
# DEBUG: {"message": "Waiting for suitable server to become available", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "remainingTimeMS": 29999}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 1686361308, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.014064002665691, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224793758, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 1686361308, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Stopped server monitoring", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool closed", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "previousDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 2009698804, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 10.112684991327114, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224793845, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 2009698804, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "previousDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010112684991327114>]>"}
# DEBUG: {"message": "Server selection succeeded", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010112684991327114>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection created", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Connection ready", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.20332371900440194}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.2481985159975011}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "command": "{\"aggregate\": \"cards\", \"pipeline\": [{\"$limit\": 1}, {\"$group\": {\"_id\": 1, \"n\": {\"$sum\": 1}}}], \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"GfNDc3FYQjKM2d3e3eufUw==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "aggregate", "databaseName": "mtgecorec", "requestId": 1540383426, "operationId": 1540383426, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "durationMS": 198.899, "reply": "{\"cursor\": {\"ns\": \"mtgecorec.cards\", \"firstBatch\": [{\"_id\": 1, \"n\": 1}]}, \"ok\": 1.0}", "commandName": "aggregate", "databaseName": "mtgecorec", "requestId": 1540383426, "operationId": 1540383426, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: CosmosDB cards collection accessible (contains data: True)
# DEBUG: {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010112684991327114>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010112684991327114>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0009415640088263899}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "command": "{\"find\": \"cards\", \"projection\": {\"name\": 1, \"color_identity\": 1}, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"GfNDc3FYQjKM2d3e3eufUw==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "find", "databaseName": "mtgecorec", "requestId": 304089172, "operationId": 304089172, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 2009698804, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "durationMS": 54.815000000000005, "reply": "{\"cursor\": {\"id\": 6899908936838233, \"ns\": \"mtgecorec.cards\", \"firstBatch\": [{\"_id\": {\"$oid\": \"68d04b6b8255b4901067c399\"}, \"name\": \"Forest\", \"color_identity\": [\"G\"]}, {\"_id\": {\"$oid\": \"68d04b6b8255b4901067c39a\"}, \"name\": \"Fury Sliver\", \"color_identity\": [\"R\"]}, {\"_id\": {\"$oid\": \"68d04b6b8255b4901067c39b\"}, \"name\": \"Kor Outfitter\", \"color_identity\": [\"W\"]}, {\"_id\": {\"$oid\": \"68d04b6b59fb4c414fdaa5c3\"}, \"name\": \"Spirit\", \"color_identity\": [\"W\"]}, {\"_id\": {\"$oid\": \"68d04b6b59fb4c414fdaa5c4\"}, \"name\": \"Siren Lookout\", \"color_identity\": [\"U\"]}, {\"_id\": {\"$oid\": \"68d04b6b59fb4c414fdaa5c5\"}, \"name\": \"Web\", \"color_identity\": [\"G\"]}, {\"_id\": {\"$oid\": \"68d04b6c59fb4c414fdaa5c6\"}, \"name\": \"Wastewood Verge\", \"color_identity\": [\"B\", \"G\"]}, {\"_id\": {\"$oid\": \"68d04b6c59fb4c414fdaa5c7\"}, \"name\": \"Surge of Brilliance\", \"color_identity\": [\"U\"]}, {\"_id\": {\"$oid\": \"68d04b6c59fb4c414fdaa5c8\"}, \"name\": \"Obyra's Attendants // Desperate Parry\", \"color_identity\": [\"U\"]}, {\"_id\": {\"$oid\": \"68d04b6c59fb4c414fdaa5...", "commandName": "find", "databaseName": "mtgecorec", "requestId": 304089172, "operationId": 304089172, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 2009698804, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.152658000355586, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224794359, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 2009698804, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01032067959313281>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a584abf16cc17ce47e6, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01032067959313281>]>", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0004311660013627261}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "command": "{\"getMore\": 6899908936838233, \"collection\": \"cards\", \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"GfNDc3FYQjKM2d3e3eufUw==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 35005211, "operationId": 35005211, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "durationMS": 3392.839, "reply": "{\"cursor\": {\"ns\": \"mtgecorec.cards\", \"nextBatch\": [{\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa625\"}, \"name\": \"Return to Dust\", \"color_identity\": [\"W\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa626\"}, \"name\": \"Emberheart Challenger\", \"color_identity\": [\"R\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa627\"}, \"name\": \"Royal Assassin\", \"color_identity\": [\"B\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa628\"}, \"name\": \"Shock\", \"color_identity\": [\"R\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa629\"}, \"name\": \"Eldrazi Temple\"}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa62a\"}, \"name\": \"Voyager Glidecar\", \"color_identity\": [\"W\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa62b\"}, \"name\": \"Walk the Plank\", \"color_identity\": [\"B\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa62c\"}, \"name\": \"Sphinx's Revelation\", \"color_identity\": [\"U\", \"W\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa62d\"}, \"name\": \"Mise\", \"color_identity\": [\"U\"]}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa62e\"}, \"name\": \"Kor Entanglers\", \"color_identity\": [\"...", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 35005211, "operationId": 35005211, "driverConnectionId": 1, "serverConnectionId": 878900582, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a584abf16cc17ce47e6"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# INFO: Loaded color identity for 110031 cards from CosmosDB
# INFO: Loading all card data from CosmosDB...
# INFO: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
# DEBUG: {"message": "Starting topology monitoring", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "previousDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# DEBUG: {"message": "Starting server monitoring", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Waiting for suitable server to become available", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "remainingTimeMS": 29999}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverConnectionId": 573481588, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 107.53102299349848, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224798049, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 573481588, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Stopped server monitoring", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool closed", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "previousDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverConnectionId": 1062864141, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 10.80841499788221, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224798105, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 1062864141, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "previousDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01080841499788221>]>"}
# DEBUG: {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01080841499788221>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection created", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Connection ready", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.05838087400479708}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.09890456600987818}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "command": "{\"find\": \"cards\", \"projection\": {\"name\": 1, \"color_identity\": 1, \"type_line\": 1, \"oracle_text\": 1, \"cmc\": 1, \"set\": 1, \"rarity\": 1, \"detected_mechanics\": 1, \"mechanic_count\": 1, \"is_infinite_combo\": 1, \"is_aristocrats\": 1, \"is_ramp\": 1, \"is_removal\": 1, \"is_card_draw\": 1, \"is_board_wipe\": 1, \"is_tokens\": 1, \"is_counters\": 1, \"is_graveyard\": 1, \"is_voltron\": 1, \"is_protection\": 1, \"is_tutor\": 1, \"is_finisher\": 1, \"is_utility\": 1}, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PmtVmte+TwacRU3LJqvZag==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "find", "databaseName": "mtgecorec", "requestId": 2145174067, "operationId": 2145174067, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "durationMS": 162.882, "reply": "{\"cursor\": {\"id\": 5916880605054686, \"ns\": \"mtgecorec.cards\", \"firstBatch\": [{\"_id\": {\"$oid\": \"68d04b6b8255b4901067c399\"}, \"name\": \"Forest\", \"color_identity\": [\"G\"], \"type_line\": \"Basic Land \u2014 Forest\", \"oracle_text\": \"({T}: Add {G}.)\", \"set\": \"blb\", \"rarity\": \"common\"}, {\"_id\": {\"$oid\": \"68d04b6b8255b4901067c39a\"}, \"name\": \"Fury Sliver\", \"color_identity\": [\"R\"], \"type_line\": \"Creature \u2014 Sliver\", \"oracle_text\": \"All Sliver creatures have double strike.\", \"cmc\": 6.0, \"set\": \"tsp\", \"rarity\": \"uncommon\", \"detected_mechanics\": [\"flying\", \"cast\"], \"mechanic_count\": 2, \"is_counters\": true, \"is_finisher\": true}, {\"_id\": {\"$oid\": \"68d04b6b8255b4901067c39b\"}, \"name\": \"Kor Outfitter\", \"color_identity\": [\"W\"], \"type_line\": \"Creature \u2014 Kor Soldier\", \"oracle_text\": \"When this creature enters, you may attach target Equipment you control to target creature you control.\", \"cmc\": 2.0, \"set\": \"zen\", \"rarity\": \"common\", \"detected_mechanics\": [\"large\", \"group\"], \"mechanic_count\": 2, \"is_voltr...", "commandName": "find", "databaseName": "mtgecorec", "requestId": 2145174067, "operationId": 2145174067, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01080841499788221>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.01080841499788221>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0006853730010334402}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "command": "{\"getMore\": 5916880605054686, \"collection\": \"cards\", \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PmtVmte+TwacRU3LJqvZag==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 468703135, "operationId": 468703135, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverConnectionId": 1062864141, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "driverConnectionId": 1, "serverConnectionId": 1062864141, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.280962993623689, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224798618, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 1062864141, \"ok\": 1.0}"}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "durationMS": 2856.486, "reply": "{\"cursor\": {\"id\": 5916880605054686, \"ns\": \"mtgecorec.cards\", \"nextBatch\": [{\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa625\"}, \"name\": \"Return to Dust\", \"color_identity\": [\"W\"], \"type_line\": \"Instant\", \"oracle_text\": \"Exile target artifact or enchantment. If you cast this spell during your main phase, you may exile up to one other target artifact or enchantment.\", \"cmc\": 4.0, \"set\": \"khc\", \"rarity\": \"uncommon\", \"detected_mechanics\": [\"flying\", \"cast\"], \"mechanic_count\": 2, \"is_removal\": true}, {\"_id\": {\"$oid\": \"68d04b7059fb4c414fdaa626\"}, \"name\": \"Emberheart Challenger\", \"color_identity\": [\"R\"], \"type_line\": \"Creature \u2014 Mouse Warrior\", \"oracle_text\": \"Haste\nProwess (Whenever you cast a noncreature spell, this creature gets +1/+1 until end of turn.)\nValiant \u2014 Whenever this creature becomes the target of a spell or ability you control for the first time each turn, exile the top card of your library. Until end of turn, you may play that card.\", \"cmc\": 2.0, \"set\": \"blb\", \"rarity\": \"r...", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 468703135, "operationId": 468703135, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0007550849986728281}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "command": "{\"getMore\": 5916880605054686, \"collection\": \"cards\", \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PmtVmte+TwacRU3LJqvZag==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1801979802, "operationId": 1801979802, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "durationMS": 2646.4210000000003, "reply": "{\"cursor\": {\"id\": 5916880605054686, \"ns\": \"mtgecorec.cards\", \"nextBatch\": [{\"_id\": {\"$oid\": \"68d0518659fb4c414fdb1730\"}, \"name\": \"Sylvan Ranger\", \"color_identity\": [\"G\"], \"type_line\": \"Creature \u2014 Elf Scout Ranger\", \"oracle_text\": \"When this creature enters, you may search your library for a basic land card, reveal it, put it into your hand, then shuffle.\", \"cmc\": 2.0, \"set\": \"ddh\", \"rarity\": \"common\"}, {\"_id\": {\"$oid\": \"68d0518659fb4c414fdb1731\"}, \"name\": \"Misfortune Teller\", \"color_identity\": [\"B\"], \"type_line\": \"Creature \u2014 Human Warlock\", \"oracle_text\": \"Deathtouch\nWhenever this creature enters or deals combat damage to a player, exile target card from a graveyard. If it was a creature card, create a 2/2 black Rogue creature token. If it was a land card, create a Treasure token. Otherwise, you gain 3 life.\", \"cmc\": 4.0, \"set\": \"prm\", \"rarity\": \"rare\", \"detected_mechanics\": [\"cast\", \"create\", \"tokens\"], \"mechanic_count\": 3, \"is_ramp\": true, \"is_removal\": true, \"is_tokens\": ...", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1801979802, "operationId": 1801979802, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.00039610300154890865}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "command": "{\"getMore\": 5916880605054686, \"collection\": \"cards\", \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PmtVmte+TwacRU3LJqvZag==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1315634022, "operationId": 1315634022, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 2009698804, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a584abf16cc17ce47e6"}, "driverConnectionId": 1, "serverConnectionId": 2009698804, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 9.695556000224315, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224804388, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 2009698804, \"ok\": 1.0}"}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "durationMS": 2724.1870000000004, "reply": "{\"cursor\": {\"id\": 5916880605054686, \"ns\": \"mtgecorec.cards\", \"nextBatch\": [{\"_id\": {\"$oid\": \"68d0586859fb4c414fdb9471\"}, \"name\": \"Fires of Invention\", \"color_identity\": [\"R\"], \"type_line\": \"Enchantment\", \"oracle_text\": \"You can cast spells only during your turn and you can cast no more than two spells each turn.\nYou may cast spells with mana value less than or equal to the number of lands you control without paying their mana costs.\", \"cmc\": 4.0, \"set\": \"eld\", \"rarity\": \"rare\"}, {\"_id\": {\"$oid\": \"68d0586859fb4c414fdb9472\"}, \"name\": \"Weeping Angel\", \"color_identity\": [\"B\", \"U\"], \"type_line\": \"Artifact Creature \u2014 Alien Angel\", \"oracle_text\": \"Flash\nFirst strike, vigilance\nWhenever an opponent casts a creature spell, this creature isn't a creature until end of turn.\nIf this creature would deal combat damage to a creature, prevent that damage and that creature's owner shuffles it into their library.\", \"cmc\": 3.0, \"set\": \"who\", \"rarity\": \"rare\", \"detected_mechanics\": [\"flying\", \"ca...", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1315634022, "operationId": 1315634022, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "<function any_server_selector at 0x7f6768e1ab60>", "operation": "getMore", "topologyDescription": "<TopologyDescription id: 69743a5d4abf16cc17ce47e7, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.010902924597030506>]>", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0005763569934060797}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "command": "{\"getMore\": 5916880605054686, \"collection\": \"cards\", \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"PmtVmte+TwacRU3LJqvZag==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1369133069, "operationId": 1369133069, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "durationMS": 232.28099999999998, "reply": "{\"cursor\": {\"ns\": \"mtgecorec.cards\", \"nextBatch\": [{\"_id\": {\"$oid\": \"68d05fd359fb4c414fdc18c1\"}, \"name\": \"Kykar, Zephyr Awakener\", \"color_identity\": [\"U\", \"W\"], \"type_line\": \"Legendary Creature \u2014 Bird Wizard\", \"oracle_text\": \"Flying\nWhenever you cast a noncreature spell, choose one \u2014\n\u2022 Exile another target creature you control. Return that card to the battlefield under its owner's control at the beginning of the next end step.\n\u2022 Create a 1/1 white Spirit creature token with flying.\", \"cmc\": 4.0, \"set\": \"fdn\", \"rarity\": \"rare\"}, {\"_id\": {\"$oid\": \"68d05fd359fb4c414fdc18c2\"}, \"name\": \"Benthic Biomancer\", \"color_identity\": [\"U\"], \"type_line\": \"Creature \u2014 Merfolk Wizard Mutant\", \"oracle_text\": \"{1}{U}: Adapt 1. (If this creature has no +1/+1 counters on it, put a +1/+1 counter on it.)\nWhenever one or more +1/+1 counters are put on this creature, draw a card, then discard a card.\", \"cmc\": 1.0, \"set\": \"prna\", \"rarity\": \"rare\"}, {\"_id\": {\"$oid\": \"68d05fd359fb4c414f...", "commandName": "getMore", "databaseName": "mtgecorec", "requestId": 1369133069, "operationId": 1369133069, "driverConnectionId": 1, "serverConnectionId": 311782169, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a5d4abf16cc17ce47e7"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:235: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['is_infinite_combo'] = df['is_infinite_combo'].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# /workspaces/mtgecorec/core/data_engine/card_scoring.py:245: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df[flag] = df[flag].fillna(False).astype(bool)
# INFO: Loaded 110031 cards from CosmosDB (replacing CSV data)
# INFO:   - 23552 cards with detected mechanics
# INFO:   - 110031 cards with archetype assignments
# INFO: Lookup tables built
# INFO: CardScorer initialized successfully
# ✓ CardScorer initialized
#   - Total cards loaded: 110031
#   - Color identity lookup entries: 35510
#   - Mechanic weights loaded: 50
#
#   Sample color identity data:
#     Forest: {'G'}
#     Fury Sliver: {'R'}
#     Kor Outfitter: {'W'}

# %%
# Verify CosmosDB connection and color_identity field
print("\n" + "="*70)
print("VERIFYING COSMOSDB COLOR IDENTITY FIELD")
print("="*70)

try:
    from core.data_engine.cosmos_driver import get_mongo_client, get_collection
    
    client = get_mongo_client()
    import os
    db_name = os.environ.get('COSMOS_DB_NAME', 'cards')
    collection_name = 'cards'
    
    cards_collection = get_collection(client, db_name, collection_name)
    
    # Check collection size
    count = cards_collection.count_documents({})
    print(f"✓ Connection to CosmosDB successful")
    print(f"  Database: {db_name}")
    print(f"  Collection: {collection_name}")
    print(f"  Total documents: {count}")
    
    if count > 0:
        # Get a sample document and show its structure
        sample = cards_collection.find_one()
        print(f"\n  Sample document keys: {list(sample.keys())}")
        
        # Check specifically for color_identity
        if 'color_identity' in sample:
            print(f"  ✓ color_identity field FOUND: {sample.get('color_identity')}")
        else:
            print(f"  ✗ color_identity field NOT FOUND in database!")
            print(f"    Available fields: {list(sample.keys())}")
    else:
        print(f"\n  ✗ No cards found in collection!")
        
except Exception as e:
    print(f"✗ Exception during CosmosDB verification: {e}")
    import traceback
    traceback.print_exc()

print("="*70)
# Out:
# INFO: You appear to be connected to a CosmosDB cluster. For more information regarding feature compatibility and support please visit https://www.mongodb.com/supportability/cosmosdb
# DEBUG: {"message": "Starting topology monitoring", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "previousDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: Unknown, servers: []>", "newDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# DEBUG: {"message": "Starting server monitoring", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Server selection started", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}}
# DEBUG: {"message": "Waiting for suitable server to become available", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "remainingTimeMS": 29998}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverConnectionId": 1487680240, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.484892995213158, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224813055, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 1487680240, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool created", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "maxIdleTimeMS": 120000.0}
# DEBUG: {"message": "Stopped server monitoring", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection pool closed", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "previousDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>"}
# ======================================================================
# VERIFYING COSMOSDB COLOR IDENTITY FIELD
# ======================================================================
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverConnectionId": 58200271, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.343863006914034, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224813143, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 58200271, \"ok\": 1.0}"}
# DEBUG: {"message": "Connection pool ready", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Topology description changed", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "previousDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetNoPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: Unknown, rtt: None>]>", "newDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.011343863006914034>]>"}
# DEBUG: {"message": "Server selection succeeded", "selector": "Primary()", "operation": "count", "topologyDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.011343863006914034>]>", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection created", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Connection ready", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.06644683200283907}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.10697705099300947}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "command": "{\"aggregate\": \"cards\", \"pipeline\": [{\"$group\": {\"_id\": 1, \"n\": {\"$sum\": 1}}}], \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"WZzkgRzPQaunUIQj/qWXBQ==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "aggregate", "databaseName": "mtgecorec", "requestId": 859484421, "operationId": 859484421, "driverConnectionId": 1, "serverConnectionId": 1043715684, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "durationMS": 385.357, "reply": "{\"cursor\": {\"ns\": \"mtgecorec.cards\", \"firstBatch\": [{\"_id\": 1, \"n\": 110031}]}, \"ok\": 1.0}", "commandName": "aggregate", "databaseName": "mtgecorec", "requestId": 859484421, "operationId": 859484421, "driverConnectionId": 1, "serverConnectionId": 1043715684, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# DEBUG: {"message": "Server selection started", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.011343863006914034>]>", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}}
# DEBUG: {"message": "Server selection succeeded", "selector": "Primary()", "operation": "find", "topologyDescription": "<TopologyDescription id: 69743a6c4abf16cc17ce47e8, topology_type: ReplicaSetWithPrimary, servers: [<ServerDescription ('mtgecorec-westus2.mongo.cosmos.azure.com', 10255) server_type: RSPrimary, rtt: 0.011343863006914034>]>", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checkout started", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked out", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1, "durationMS": 0.0007691890059504658}
# DEBUG: {"message": "Command started", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "command": "{\"find\": \"cards\", \"limit\": 1, \"singleBatch\": true, \"lsid\": {\"id\": {\"$binary\": {\"base64\": \"WZzkgRzPQaunUIQj/qWXBQ==\", \"subType\": \"04\"}}}, \"$db\": \"mtgecorec\"}", "commandName": "find", "databaseName": "mtgecorec", "requestId": 1914544919, "operationId": 1914544919, "driverConnectionId": 1, "serverConnectionId": 1043715684, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverConnectionId": 58200271, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "driverConnectionId": 1, "serverConnectionId": 58200271, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.279690006631427, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224813660, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 58200271, \"ok\": 1.0}"}
# DEBUG: {"message": "Command succeeded", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "durationMS": 37.54600000000001, "reply": "{\"cursor\": {\"ns\": \"mtgecorec.cards\", \"firstBatch\": [{\"_id\": {\"$oid\": \"68d04b6b8255b4901067c399\"}, \"object\": \"card\", \"id\": \"0000419b-0bba-4488-8f7a-6194544ce91e\", \"oracle_id\": \"b34bb2dc-c1af-4d77-b0b3-a0fb342a5fc6\", \"multiverse_ids\": [668564], \"mtgo_id\": 129825, \"arena_id\": 91829, \"tcgplayer_id\": 558404, \"cardmarket_id\": 777725, \"name\": \"Forest\", \"lang\": \"en\", \"released_at\": \"2024-08-02\", \"uri\": \"https://api.scryfall.com/cards/0000419b-0bba-4488-8f7a-6194544ce91e\", \"scryfall_uri\": \"https://scryfall.com/card/blb/280/forest?utm_source=api\", \"layout\": \"normal\", \"highres_image\": true, \"image_status\": \"highres_scan\", \"image_uris\": {\"small\": \"https://cards.scryfall.io/small/front/0/0/0000419b-0bba-4488-8f7a-6194544ce91e.jpg?1721427487\", \"normal\": \"https://cards.scryfall.io/normal/front/0/0/0000419b-0bba-4488-8f7a-6194544ce91e.jpg?1721427487\", \"large\": \"https://cards.scryfall.io/large/front/0/0/0000419b-0bba-4488-8f7a-6194544ce91e.jpg?1721427487\", \"png\": \"https://cards.scryfall.io/png/front/0/...", "commandName": "find", "databaseName": "mtgecorec", "requestId": 1914544919, "operationId": 1914544919, "driverConnectionId": 1, "serverConnectionId": 1043715684, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255}
# DEBUG: {"message": "Connection checked in", "clientId": {"$oid": "69743a6c4abf16cc17ce47e8"}, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "driverConnectionId": 1}
# ✓ Connection to CosmosDB successful
#   Database: mtgecorec
#   Collection: cards
#   Total documents: 110031
#
#   Sample document keys: ['_id', 'object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors', 'color_identity', 'keywords', 'produced_mana', 'legalities', 'games', 'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame', 'full_art', 'textless', 'booster', 'story_spotlight', 'prices', 'related_uris', 'purchase_uris', 'day_uploaded', 'pricing', 'last_price_update']
#   ✓ color_identity field FOUND: ['G']
# ======================================================================

# %% [markdown]
# ## Section 2: Color Identity Enforcement
#
# Test strict Commander format color identity enforcement.

# %%
# Test extract_color_identity() method
print("\n" + "="*70)
print("TESTING COLOR IDENTITY EXTRACTION")
print("="*70)

test_card_names = [
    'Meren of Clan Nel Toth',
    'Lightning Bolt',
    'Sol Ring',
    'Counterspell'
]

for card_name in test_card_names:
    # Try exact match first, then case-insensitive
    card_matches = scorer.all_cards[scorer.all_cards['name'] == card_name]
    if len(card_matches) == 0:
        card_matches = scorer.all_cards[
            scorer.all_cards['name'].str.lower() == card_name.lower()
        ]
    
    if len(card_matches) > 0:
        card = card_matches.iloc[0].to_dict()
        colors = scorer.extract_color_identity(card)
        print(f"{card_name:40s} → {colors if colors else {'colorless'}}")
    else:
        print(f"{card_name:40s} → NOT FOUND in {len(scorer.all_cards)} cards")

print("="*70)
# Out:
# ======================================================================
# TESTING COLOR IDENTITY EXTRACTION
# ======================================================================
# Meren of Clan Nel Toth                   → {'B', 'G'}
# Lightning Bolt                           → {'R'}
# Sol Ring                                 → {'colorless'}
# Counterspell                             → {'U'}
# ======================================================================

# %%
# DEBUG: Check what's actually in the lookup
print("\n" + "="*70)
print("DEBUG: LOOKUP CONTENTS")
print("="*70)

print(f"Total entries in color_identity_lookup: {len(scorer.color_identity_lookup)}")

# Search for cards with "lightning" or "sol" in name
search_terms = ["lightning", "sol ring"]
for term in search_terms:
    matching_keys = [k for k in scorer.color_identity_lookup.keys() if term.lower() in k.lower()]
    print(f"\nCards matching '{term}':")
    if matching_keys:
        for key in matching_keys[:5]:  # Show first 5
            print(f"  - '{key}': {scorer.color_identity_lookup[key]}")
    else:
        print(f"  (none found)")

# Check if they're in all_cards
print(f"\n'Lightning Bolt' in all_cards: {len(scorer.all_cards[scorer.all_cards['name'].str.contains('Lightning Bolt', case=False, na=False)]) > 0}")
print(f"'Sol Ring' in all_cards: {len(scorer.all_cards[scorer.all_cards['name'].str.contains('Sol Ring', case=False, na=False)]) > 0}")

print("="*70)
# Out:
# ======================================================================
# DEBUG: LOOKUP CONTENTS
# ======================================================================
# Total entries in color_identity_lookup: 35510
#
# Cards matching 'lightning':
#   - 'Lightning Shrieker': {'R'}
#   - 'Homing Lightning': {'R'}
#   - 'Lightning Elemental': {'R'}
#   - 'Living Lightning': {'R'}
#   - 'Lightning Axe': {'R'}
#
# Cards matching 'sol ring':
#   - 'Sol Ring': set()
#   - 'Sol Ring // Sol Ring': set()
#
# 'Lightning Bolt' in all_cards: True
# 'Sol Ring' in all_cards: True
# ======================================================================

# %%
# Test strict color identity enforcement
print("\n" + "="*70)
print("COLOR IDENTITY STRICT ENFORCEMENT TEST")
print("="*70)

# Test commander: Meren (Black/Green)
meren_matches = scorer.all_cards[scorer.all_cards['name'] == 'Meren of Clan Nel Toth']
if len(meren_matches) == 0:
    print("ERROR: Meren not found in database")
else:
    meren = meren_matches.iloc[0].to_dict()
    meren_colors = scorer.extract_color_identity(meren)
    
    print(f"\nCommander: Meren of Clan Nel Toth")
    print(f"Color identity: {meren_colors}")
    print(f"Legal colors: Black (B), Green (G), Colorless")
    print(f"Database has {len(scorer.all_cards)} cards total")
    
    # Test cards from database
    test_cards = [
        ('Lightning Bolt', False),        # Red - should be illegal
        ('Counterspell', False),          # Blue - should be illegal
        ('Sol Ring', True),               # Colorless - should be legal
        ('Swords to Plowshares', False),  # White - should be illegal
        ('Llanowar Elves', True),         # Green - should be legal
    ]
    
    print(f"\nTesting color identity enforcement:")
    all_passed = True
    found_count = 0
    
    for card_name, expected_legal in test_cards:
        card_matches = scorer.all_cards[scorer.all_cards['name'] == card_name]
        
        if len(card_matches) > 0:
            found_count += 1
            card = card_matches.iloc[0].to_dict()
            card_colors = scorer.extract_color_identity(card)
            multiplier = scorer._calculate_color_multiplier(card_colors, meren_colors)
            
            # Check if result matches expectation
            is_legal = multiplier > 0.0
            
            status = "✓ PASS" if (is_legal == expected_legal) else "✗ FAIL"
            if is_legal != expected_legal:
                all_passed = False
            
            color_str = str(card_colors) if card_colors else "colorless"
            expected_str = "LEGAL" if expected_legal else "ILLEGAL"
            print(f"  {status} {card_name:30s} colors={color_str:20s} multiplier={multiplier:.2f} (expected: {expected_str})")
        else:
            print(f"  ⚠ SKIP {card_name:30s} (not in database)")
    
    print("\n" + "="*70)
    print(f"Found {found_count}/{len(test_cards)} test cards")
    if all_passed and found_count > 0:
        print("✓✓✓ COLOR IDENTITY TEST PASSED ✓✓✓")
    elif found_count == 0:
        print("⚠ No test cards found in database")
    else:
        print("✗✗✗ COLOR IDENTITY TEST FAILED ✗✗✗")
    print("="*70)
# Out:
# ======================================================================
# COLOR IDENTITY STRICT ENFORCEMENT TEST
# ======================================================================
#
# Commander: Meren of Clan Nel Toth
# Color identity: {'B', 'G'}
# Legal colors: Black (B), Green (G), Colorless
# Database has 110031 cards total
#
# Testing color identity enforcement:
#   ✓ PASS Lightning Bolt                 colors={'R'}                multiplier=0.00 (expected: ILLEGAL)
#   ✓ PASS Counterspell                   colors={'U'}                multiplier=0.00 (expected: ILLEGAL)
#   ✓ PASS Sol Ring                       colors=colorless            multiplier=1.00 (expected: LEGAL)
#   ✓ PASS Swords to Plowshares           colors={'W'}                multiplier=0.00 (expected: ILLEGAL)
#   ✓ PASS Llanowar Elves                 colors={'G'}                multiplier=1.00 (expected: LEGAL)
#
# ======================================================================
# Found 5/5 test cards
# ✓✓✓ COLOR IDENTITY TEST PASSED ✓✓✓
# ======================================================================

# %% [markdown]
# ## Section 3: Debug Mechanic Synergy Calculation
#
# Test mechanic extraction and identify why synergy always returns 100.

# %%
# Test mechanic extraction
print("\n" + "="*70)
print("MECHANIC EXTRACTION TEST")
print("="*70)

test_commanders = [
    'Meren of Clan Nel Toth',
    'Atraxa, Praetors\' Voice', 
    'The Gitrog Monster'
]

commander_mechanics = {}

for commander_name in test_commanders:
    card_matches = scorer.all_cards[
        scorer.all_cards['name'].str.lower().str.strip() == commander_name.lower().strip()
    ]
    if len(card_matches) > 0:
        card = card_matches.iloc[0].to_dict()
        mechanics_count = float(card.get('mechanic_count', 0))
        cluster = card.get('cluster_name', 'N/A')
        archetypes = card.get('archetypes_active', 'N/A')
        
        commander_mechanics[commander_name] = mechanics_count
        
        print(f"\n{commander_name}:")
        print(f"  Mechanic count: {mechanics_count}")
        print(f"  Cluster: {cluster}")
        print(f"  Archetypes: {archetypes}")
    else:
        print(f"\n{commander_name}: NOT FOUND")

print("\n" + "="*70)
# Out:
# ======================================================================
# MECHANIC EXTRACTION TEST
# ======================================================================
#
# Meren of Clan Nel Toth:
#   Mechanic count: 2.0
#   Cluster: N/A
#   Archetypes: N/A
#
# Atraxa, Praetors' Voice:
#   Mechanic count: 3.0
#   Cluster: N/A
#   Archetypes: N/A
#
# The Gitrog Monster:
#   Mechanic count: 2.0
#   Cluster: N/A
#   Archetypes: N/A
#
# ======================================================================

# %%
# Test synergy calculation with detailed logging
print("\n" + "="*70)
print("SYNERGY CALCULATION DEBUG")
print("="*70)

# Get Meren
meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]
if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    
    # Test synergy for a few cards
    test_card_names = [
        'Sol Ring',
        'Sakura-Tribe Elder',
        'Counterspell',
        'Crucible of Worlds'
    ]
    
    print(f"\nTesting synergy calculation for Meren:")
    
    synergy_scores = []
    for card_name in test_card_names:
        card_matches = scorer.all_cards[
            scorer.all_cards['name'].str.lower().str.strip() == card_name.lower().strip()
        ]
        if len(card_matches) > 0:
            card = card_matches.iloc[0].to_dict()
            synergy = scorer._calculate_mechanic_synergy(card, meren, [])
            synergy_scores.append(synergy)
            print(f"  {card_name:30s} synergy={synergy:6.2f}")
        else:
            print(f"  {card_name:30s} NOT FOUND")
    
    if synergy_scores:
        avg_synergy = np.mean(synergy_scores)
        min_synergy = np.min(synergy_scores)
        max_synergy = np.max(synergy_scores)
        print(f"\nSynergy statistics:")
        print(f"  Average: {avg_synergy:.2f}")
        print(f"  Min: {min_synergy:.2f}")
        print(f"  Max: {max_synergy:.2f}")
        print(f"\n⚠ Issue: All synergy scores the same? {len(set(synergy_scores)) == 1}")

print("\n" + "="*70)
# Out:
# ======================================================================
# SYNERGY CALCULATION DEBUG
# ======================================================================
#
# Testing synergy calculation for Meren:
# DEBUG:
# === SYNERGY DEBUG: Sol Ring vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
#   Sol Ring                       synergy=  0.00
# DEBUG:
# === SYNERGY DEBUG: Sakura-Tribe Elder vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
#   Sakura-Tribe Elder             synergy=  0.00
# DEBUG:
# === SYNERGY DEBUG: Counterspell vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
#   Counterspell                   synergy=100.00
# DEBUG:
# === SYNERGY DEBUG: Crucible of Worlds vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
#   Crucible of Worlds             synergy=100.00
#
# Synergy statistics:
#   Average: 50.00
#   Min: 0.00
#   Max: 100.00
#
# ⚠ Issue: All synergy scores the same? False
#
# ======================================================================

# %% [markdown]
# ## Section 4: Deduplicate Cards in Results
#
# Verify that score_all_cards() properly deduplicates and filters illegal cards.

# %%
# Score all cards for Meren and check deduplication
print("\n" + "="*70)
print("DEDUPLICATION AND FILTERING TEST")
print("="*70)

meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]
if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    
    print(f"\nScoring all cards for Meren...")
    
    # Score all cards
    results_df = scorer.score_all_cards(meren, [])
    
    print(f"\nResults:")
    print(f"  Total unique cards: {len(results_df)}")
    print(f"  Duplicate card names: {results_df['card_name'].duplicated().sum()}")
    print(f"  Cards with color_multiplier = 0: {(results_df['color_multiplier'] == 0).sum()}")
    
    # Check for illegal cards in top 100
    top_100 = results_df.head(100)
    illegal_in_top = (top_100['color_multiplier'] == 0).sum()
    print(f"  Illegal cards in top 100: {illegal_in_top}")
    
    if illegal_in_top == 0:
        print("\n✓ PASS: No illegal cards in top 100 recommendations")
    else:
        print(f"\n✗ FAIL: Found {illegal_in_top} illegal cards in top 100!")
    
    print("\n" + "="*70)
# Out:
# ======================================================================
# DEDUPLICATION AND FILTERING TEST
# ======================================================================
# INFO: Scoring all cards for Meren of Clan Nel Toth
# Scoring all cards for Meren...
# INFO: After deduplication: 35510 unique cards (from 110031 total)
# DEBUG:
# === SYNERGY DEBUG: Forest vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Fury Sliver vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Kor Outfitter vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Spirit vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Siren Lookout vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Web vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Wastewood Verge vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Surge of Brilliance vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast', 'exile'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Obyra's Attendants // Desperate Parry vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Venerable Knight vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Wildcall vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'small', 'group'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 50.0
# DEBUG: Final synergy: 50.0
# DEBUG:
# === SYNERGY DEBUG: Fell Beast's Shriek // Fell Beast's Shriek vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mystic Skyfish vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Swamp vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Battlewing Mystic vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Birds of Paradise vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Bronze Horse vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Wall of Vipers vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Admiral Beckett Brass vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ragged Playmate vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mulch vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Whiptongue Hydra vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Wall of Roots vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Pugnacious Hammerskull vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: War Historian vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Searing Blaze vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Siren's Call vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mystical Tutor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Essence Warden vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Blood Operative vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Selvala's Enforcer vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Coalstoke Gearhulk vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Fresh Meat vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Orzhov Guildgate vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mortify vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Bird vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Narset, Parter of Veils vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Paradise Druid vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Run Away Together vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Sinew Sliver vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Charge vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Island vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Novice Knight vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Fallen Askari vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'small', 'group'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 50.0
# DEBUG: Final synergy: 50.0
# DEBUG:
# === SYNERGY DEBUG: Altar's Reap vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Lavinia, Azorius Renegade vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Odric, Master Tactician vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Afflict vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Crown of Gondor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Invisible Stalker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Dakkon, Shadow Slayer vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Shahrazad vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Destructive Tampering vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mox Jet vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Harmonize vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Nocturnal Raid vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Temporal Manipulation vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: The Convincing General vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Archon of the Wild Rose vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Vaevictis Asmadi vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Flensermite vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Triskelion vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Rite of the Raging Storm vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Gorion, Wise Mentor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Wolf vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Gate Smasher vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Balamb Garden, SeeD Academy // Balamb Garden, Airborne vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Kemba's Outfitter vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: World Breaker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Rogue Kavu vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ornery Tumblewagg vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast', 'exile'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Harbinger of the Seas vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mad Auntie vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Coral Eel vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Midnight Clock vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Invasion of Tolvada // The Broken Sky vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: The Great Juggernaut vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Lurking Nightstalker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Spark Spray vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Remand vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Eumidian Hatchery vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Lazav, Familiar Stranger vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Plains vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Edric, Spymaster of Trest vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Clearwater Pathway // Clearwater Pathway vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Crossbow Infantry vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Bubbling Beebles vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Second Breakfast vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ulasht, the Hate Seed vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Unholy Strength vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Consecrate // Consume vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Thornwood Falls vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Goblin Bowling Team vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Elvish Aberration vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'high', 'complexity', 'outliers'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Farid, Enterprising Salvager vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Wings of Aesthir vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mwonvuli Beast Tracker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Return to Dust vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Emberheart Challenger vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Royal Assassin vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Shock vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Eldrazi Temple vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Voyager Glidecar vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Walk the Plank vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Sphinx's Revelation vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mise vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Kor Entanglers vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Tail Swipe vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Briarbridge Patrol vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: The Restoration of Eiganjo // Architect of Restoration vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Spread the Sickness vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'counter', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Izoni, Thousand-Eyed vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'counter', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Oracle of the Alpha vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Alesha, Who Laughs at Fate vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Duelist's Heritage vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Lazav, Dimir Mastermind vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Celestial Kirin vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Courage in Crisis vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Green Sun's Twilight vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Talisman of Curiosity vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Snapdax, Apex of the Hunt vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast', 'exile'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ornithopter vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Kamahl, Pit Fighter vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Saheeli's Directive vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'counter', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Festering Goblin vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Reality Smasher vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Growing Rites of Itlimoc // Itlimoc, Cradle of the Sun vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Orzhov Advokist vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Initiate's Companion vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Tsabo's Assassin vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Mana Clash vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'small', 'group'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 50.0
# DEBUG: Final synergy: 50.0
# DEBUG:
# === SYNERGY DEBUG: Darksteel Splicer vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Hogaak, Arisen Necropolis vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Survival of the Fittest vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Keen-Eyed Curator vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Jasmine Boreal vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Bone Dragon vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Psychic Venom vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Birthing Ritual vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Sokka's Haiku vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: A-Falcon Abomination vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Fire Elemental vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Grizzly Fate vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ancient Spring vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Howlgeist vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Sengir Vampire vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Farewell vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Digsite Engineer vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Security Rhox vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Biogenic Upgrade vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Belbe's Armor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Slinking Skirge vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Thalakos Lowlands vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Scoured Barrens vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Shaile, Dean of Radiance // Embrose, Dean of Shadow vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Spined Wurm vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Behemoth Sledge vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Cadric, Soul Kindler vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Summon: Choco/Mog vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Grim Captain's Call vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Boseiju, Who Endures vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Copy vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Reassembling Skeleton vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Catastrophe vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Vandalblast vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'counter', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Beledros Witherbloom vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Enchanted Carriage vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Insect vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Workshop Elders vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Floodbringer vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Phyresis vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Banewhip Punisher vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mountain vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Nin, the Pain Artist vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Corpse Traders vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Zodiac Rabbit vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Rite of the Serpent vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Scourge of Fleets vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Maro's Gone Nuts vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Skullclamp vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Skullmane Baku vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Feeling of Dread vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ledger Shredder vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Pia Nalaar vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Shatterskull Charger vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Infected Vermin vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Venerable Warsinger vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Thousand-Faced Shadow vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Delney, Streetwise Lookout vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Murderous Betrayal vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Eyeblight Massacre vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Raise Dead vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Hero vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Saprazzan Skerry vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Elder Gargaroth vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Bloodline Culling vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Jan Tomcani Bio vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Enigma Drake vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Sphinx Summoner vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Blessing of Frost vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Saproling vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Worship vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Duress vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Miara, Thorn of the Glade vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Flame Slash vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# ...
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ancient Den vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Sek'Kuar, Deathkeeper vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Pit Scorpion vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Ceremonial Groundbreaker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Conservator vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Fumiko the Lowblood vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'small', 'group'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 50.0
# DEBUG: Final synergy: 50.0
# DEBUG:
# === SYNERGY DEBUG: Ancient Brontodon vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Booster Tutor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Djinn of Wishes vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Vertigo vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Zodiac Monkey vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Anthem of Champions vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Runes of the Deus vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Yamabushi's Storm vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Jwar Isle Avenger vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Contagion Clasp vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Fire Servant vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Moira, Urborg Haunt vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Cabal Therapy vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Bone Shaman vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Idyllic Tutor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Bombard vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Spike Colony vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Diabolic Servitude vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Subterranean Tremors vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Rushing River vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Feral Encounter vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Gatekeeper of Malakir vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Brood Keeper vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Time Wipe vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Fangkeeper's Familiar vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Roller Coaster vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Archangel of Tithes vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Unsummon vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Mu Yanling, Wind Rider vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Serene Sunset vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Shadowheart, Sharran Cleric vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Candlelight Vigil vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Selfless Squire vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: The Mycosynth Gardens vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Claws of Wirewood vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Dauthi Ghoul vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Calix, Guided by Fate vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'counter', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Kraul Whipcracker vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Gleancrawler vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Verdant Force vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Cleric vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ral, Monsoon Mage // Ral, Leyline Prodigy vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Ashaya, Soul of the Wild vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Blue, Loyal Raptor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast', 'exile'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Man-o'-War vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Chord of Calling vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'cast', 'exile'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Yisan, the Wanderer Bard vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Finale of Revelation vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Nicol Bolas, the Ravager // Nicol Bolas, the Arisen vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Stock Up vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Lightstall Inquisitor vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Piper of the Swarm vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Furnace Brood vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Trusty Companion vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Fork in the Road vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Sentinel of the Eternal Watch vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Nick Valentine, Private Eye vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Maze Behemoth vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'group', 'large'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 100.0
# DEBUG: Perfect mechanic match bonus applied: 100.0
# DEBUG: Final synergy: 100.0
# DEBUG:
# === SYNERGY DEBUG: Nettlecyst vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'tokens', 'cast', 'create'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Military Intelligence vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Spectral Searchlight vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: set()
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0
# DEBUG:
# === SYNERGY DEBUG: Noble Banneret vs Meren of Clan Nel Toth ===
# DEBUG: Card mechanics: {'flying', 'cast'}
# DEBUG: Commander mechanics: {'group', 'large'}
# DEBUG: Mechanic overlap score: 0.0
# DEBUG: Final synergy: 0.0

# %%
# Check if CardScorer supports parallel scoring
print("\n" + "="*70)
print("PERFORMANCE CHECK")
print("="*70)

import time

meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]

if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    
    print(f"\nDatabase size: {len(scorer.all_cards):,} cards")
    print(f"Testing scoring performance...")
    
    # Time the scoring
    start_time = time.time()
    results_df = scorer.score_all_cards(meren, [])
    elapsed = time.time() - start_time
    
    cards_per_sec = len(results_df) / elapsed
    
    print(f"\nResults:")
    print(f"  Cards scored: {len(results_df):,}")
    print(f"  Time elapsed: {elapsed:.2f} seconds")
    print(f"  Speed: {cards_per_sec:,.0f} cards/second")
    
    if elapsed > 10:
        print(f"\n⚠ Performance issue detected!")
        print(f"  Consider parallelization to speed this up")
    
print("="*70)

# %%
# Show top 20 recommendations
if len(results_df) > 0:
    print(f"\nTop 20 recommendations for Meren:")
    print("\n")
    
    display_cols = ['card_name', 'total_score', 'mechanic_synergy', 'archetype_fit', 'combo_bonus', 'color_multiplier']
    top_20 = results_df[display_cols].head(20)
    
    # Format for nice display
    for idx, row in top_20.iterrows():
        print(f"{idx+1:3d}. {row['card_name']:35s} Score={row['total_score']:6.2f} Synergy={row['mechanic_synergy']:6.2f} Color={row['color_multiplier']:.2f}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Show top 20 recommendations
# ----> 2 if len(results_df) > 0:
#       3     print(f"\nTop 20 recommendations for Meren:")
#       4     print("\n")
#
# NameError: name 'results_df' is not defined
# DEBUG: {"message": "Server heartbeat started", "topologyId": {"$oid": "697439e28a2ac949e563c20c"}, "driverConnectionId": 1, "serverConnectionId": 1376177638, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false}
# DEBUG: {"message": "Server heartbeat succeeded", "topologyId": {"$oid": "697439e28a2ac949e563c20c"}, "driverConnectionId": 1, "serverConnectionId": 1376177638, "serverHost": "mtgecorec-westus2.mongo.cosmos.azure.com", "serverPort": 10255, "awaited": false, "durationMS": 11.133075997349806, "reply": "{\"ismaster\": true, \"maxBsonObjectSize\": 16777216, \"maxMessageSizeBytes\": 48000000, \"maxWriteBatchSize\": 1000, \"localTime\": 1769224776607, \"logicalSessionTimeoutMinutes\": 30, \"maxWireVersion\": 21, \"tags\": {\"region\": \"West US 2\"}, \"hosts\": [\"mtgecorec-westus2.mongo.cosmos.azure.com:10255\"], \"setName\": \"globaldb\", \"setVersion\": 1, \"primary\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"me\": \"mtgecorec-westus2.mongo.cosmos.azure.com:10255\", \"connectionId\": 1376177638, \"ok\": 1.0}"}

# %% [markdown]
# ## Section 5: Validate All Critical Tests
#
# Run comprehensive validation to ensure all fixes are working correctly.

# %%
# Comprehensive validation
print("\n" + "="*70)
print("COMPREHENSIVE VALIDATION")
print("="*70)

validation_results = {}

# Test 1: Color Identity Enforcement
print("\n1. COLOR IDENTITY ENFORCEMENT")
meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]
if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    meren_colors = scorer.extract_color_identity(meren)
    
    # Test with Lightning Bolt (Red)
    bolt_matches = scorer.all_cards[
        scorer.all_cards['name'].str.lower().str.strip() == 'lightning bolt'.lower().strip()
    ]
    if len(bolt_matches) > 0:
        bolt = bolt_matches.iloc[0].to_dict()
        bolt_colors = scorer.extract_color_identity(bolt)
        multiplier = scorer._calculate_color_multiplier(bolt_colors, meren_colors)
        
        test_1_pass = multiplier == 0.0
        validation_results['color_identity'] = test_1_pass
        
        if test_1_pass:
            print("  ✓ PASS: Red card returns multiplier = 0.0 for Black/Green commander")
        else:
            print(f"  ✗ FAIL: Red card returns multiplier = {multiplier} (expected 0.0)")
    else:
        print("  ⚠ SKIP: Lightning Bolt not found in database")
        validation_results['color_identity'] = None
else:
    print("  ⚠ SKIP: Meren not found in database")
    validation_results['color_identity'] = None

# %%
# Test 2: Synergy Variance
print("\n2. SYNERGY VARIANCE")

meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]
if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    
    # Sample 100 cards and check synergy variance
    sample_cards = scorer.all_cards.sample(min(100, len(scorer.all_cards)), random_state=42)
    synergy_scores = []
    
    for _, card_row in sample_cards.iterrows():
        card = card_row.to_dict()
        synergy = scorer._calculate_mechanic_synergy(card, meren, [])
        synergy_scores.append(synergy)
    
    unique_scores = len(set(synergy_scores))
    min_synergy = min(synergy_scores)
    max_synergy = max(synergy_scores)
    
    test_2_pass = (unique_scores > 1) and (min_synergy < max_synergy)
    validation_results['synergy_variance'] = test_2_pass
    
    if test_2_pass:
        print(f"  ✓ PASS: Synergy scores vary (min={min_synergy:.1f}, max={max_synergy:.1f}, unique={unique_scores})")
    else:
        print(f"  ✗ FAIL: Synergy scores don't vary (all same value = {synergy_scores[0]})")
else:
    print("  ⚠ SKIP: Meren not found")
    validation_results['synergy_variance'] = None

# %%
# Test 3: Deduplication
print("\n3. DEDUPLICATION")

meren_matches = scorer.all_cards[
    scorer.all_cards['name'].str.lower().str.strip() == 'meren of clan nel toth'.lower().strip()
]
if len(meren_matches) > 0:
    meren = meren_matches.iloc[0].to_dict()
    results_df = scorer.score_all_cards(meren, [])
    
    has_duplicates = results_df['card_name'].duplicated().sum() > 0
    test_3_pass = not has_duplicates
    validation_results['deduplication'] = test_3_pass
    
    if test_3_pass:
        print(f"  ✓ PASS: No duplicate card names in results ({len(results_df)} unique cards)")
    else:
        print(f"  ✗ FAIL: Found {results_df['card_name'].duplicated().sum()} duplicate card names")
else:
    print("  ⚠ SKIP: Meren not found")
    validation_results['deduplication'] = None

# %%
# Test 4: Commander-Specific Results
print("\n4. COMMANDER-SPECIFIC RESULTS")

# Score for multiple commanders
commander_names = [
    'Meren of Clan Nel Toth',
    'Atraxa, Praetors\' Voice',
    'The Gitrog Monster'
]

commander_top_20s = {}
for cmd_name in commander_names:
    cmd_matches = scorer.all_cards[
        scorer.all_cards['name'].str.lower().str.strip() == cmd_name.lower().strip()
    ]
    if len(cmd_matches) > 0:
        cmd = cmd_matches.iloc[0].to_dict()
        cmd_results = scorer.score_all_cards(cmd, [])
        commander_top_20s[cmd_name] = set(cmd_results['card_name'].head(20).values)

if len(commander_top_20s) >= 2:
    # Compare first two commanders
    names = list(commander_top_20s.keys())
    top_20_1 = commander_top_20s[names[0]]
    top_20_2 = commander_top_20s[names[1]]
    
    intersection = len(top_20_1 & top_20_2)
    unique_ratio = 1.0 - (intersection / 20.0)
    
    test_4_pass = unique_ratio >= 0.5  # At least 50% different
    validation_results['commander_specific'] = test_4_pass
    
    if test_4_pass:
        print(f"  ✓ PASS: {unique_ratio*100:.1f}% unique cards between {names[0]} and {names[1]} top 20")
    else:
        print(f"  ✗ FAIL: Only {unique_ratio*100:.1f}% unique (expected ≥50%)")
else:
    print("  ⚠ SKIP: Not enough commanders found")
    validation_results['commander_specific'] = None

# %%
# Final validation summary
print("\n" + "="*70)
print("VALIDATION SUMMARY")
print("="*70)

test_names = [
    ('Color Identity Enforcement', 'color_identity'),
    ('Synergy Variance', 'synergy_variance'),
    ('Deduplication', 'deduplication'),
    ('Commander-Specific Results', 'commander_specific')
]

passed = 0
failed = 0
skipped = 0

print()
for test_name, key in test_names:
    result = validation_results.get(key)
    if result is True:
        print(f"  ✓ PASS: {test_name}")
        passed += 1
    elif result is False:
        print(f"  ✗ FAIL: {test_name}")
        failed += 1
    else:
        print(f"  ⚠ SKIP: {test_name}")
        skipped += 1

print("\n" + "="*70)
print(f"Results: {passed} PASSED, {failed} FAILED, {skipped} SKIPPED")
print("="*70)

if failed == 0 and passed > 0:
    print("\n✓✓✓ ALL VALIDATION TESTS PASSED ✓✓✓")
elif failed > 0:
    print("\n✗✗✗ SOME VALIDATION TESTS FAILED ✗✗✗")
else:
    print("\n⚠ INSUFFICIENT DATA FOR VALIDATION")
