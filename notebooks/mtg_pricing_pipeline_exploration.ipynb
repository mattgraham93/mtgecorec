# %% [markdown]
# ## 1. Setup and Imports

# %%
import pandas as pd
import numpy as np
import os
import sys
import asyncio
import requests
import time
import logging
from datetime import datetime, timezone, date
from collections import defaultdict
import warnings
warnings.filterwarnings('ignore')

# Set up logging
logging.basicConfig(level=logging.INFO, format='%(asctime)s - %(levelname)s - %(message)s')
logger = logging.getLogger(__name__)

# Add project paths for imports (notebooks folder)
sys.path.append('/workspaces/mtgecorec')
sys.path.append('/workspaces/mtgecorec/core')

# Import the simple core database driver
from core.data_engine.cosmos_driver import get_mongo_client, get_collection

print("Libraries imported successfully!")
print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
print(f"Using core cosmos_driver system")
print(f"Notebook location: /workspaces/mtgecorec/notebooks/")
# Out:
# Libraries imported successfully!
# Pandas version: 2.3.3
# NumPy version: 2.3.5
# Using core cosmos_driver system
# Notebook location: /workspaces/mtgecorec/notebooks/

# %% [markdown]
# ## 2. Database Connection

# %%
# Set up database connection with retry logic
def connect_to_database_with_retry(max_retries=3):
    """Connect to database with retry logic for connection issues"""
    for attempt in range(max_retries):
        try:
            print(f"🔄 Connection attempt {attempt + 1}/{max_retries}...")
            
            # Get fresh MongoDB client
            client = get_mongo_client()
            database_name = "mtgecorec" 
            
            # Test the connection by getting collection info
            cards_collection = get_collection(client, database_name, "cards")
            pricing_collection = get_collection(client, database_name, "card_pricing_daily")
            
            # Test with a simple query
            cards_count = cards_collection.count_documents({}, limit=1)
            
            print(f"✅ Connected to database successfully!")
            print(f"Database: {database_name}")
            print(f"Connection test: Found {cards_count:,}+ cards")
            
            return client, database_name, cards_collection, pricing_collection
            
        except Exception as e:
            print(f"❌ Connection attempt {attempt + 1} failed: {e}")
            if attempt < max_retries - 1:
                print(f"⏳ Waiting 2 seconds before retry...")
                time.sleep(2)
            else:
                print(f"💥 All connection attempts failed!")
                raise

# Connect to database
client, database_name, cards_collection, pricing_collection = connect_to_database_with_retry()
print(f"Ready to load card data...")
# Out:
# 🔄 Connection attempt 1/3...
# ✅ Connected to database successfully!
# Database: mtgecorec
# Connection test: Found 1+ cards
# Ready to load card data...

# %% [markdown]
# ## 3. Get Data

# %% [markdown]
# ### Get card data

# %%
# Load cards data efficiently - just get counts and sample for now
def load_cards_efficiently():
    """Load card data efficiently for testing without loading all 110K cards"""
    global client, cards_collection, pricing_collection
    
    try:
        print("Getting card database statistics...")
        
        # Get total count first
        total_cards = cards_collection.count_documents({})
        print(f"📊 Found {total_cards:,} total cards in database")
        
        # Get a sample of cards for structure analysis
        print("📥 Loading sample cards for analysis...")
        sample_cards = list(cards_collection.find({}).limit(100))
        print(f"✅ Successfully loaded {len(sample_cards)} sample cards")
        
        # Create DataFrame from sample for structure analysis
        df_sample = pd.DataFrame(sample_cards)
        
        return df_sample, total_cards
        
    except Exception as e:
        print(f"❌ Error loading cards: {e}")
        print("🔄 Attempting to reconnect...")
        
        # Try to reconnect
        client, _, cards_collection, pricing_collection = connect_to_database_with_retry()
        
        # Retry with sample
        total_cards = cards_collection.count_documents({})
        sample_cards = list(cards_collection.find({}).limit(100))
        df_sample = pd.DataFrame(sample_cards)
        print(f"✅ Successfully loaded sample after reconnection")
        return df_sample, total_cards

# Load the cards efficiently
df_cards, total_card_count = load_cards_efficiently()

if len(df_cards) > 0:
    print(f"\nSample DataFrame shape: {df_cards.shape}")
    print(f"Total cards in database: {total_card_count:,}")
    print(f"Sample columns: {list(df_cards.columns)}")
    
    # Show sample data
    print("\n=== SAMPLE CARDS DATA ===")
    display_cols = ['id', 'name', 'type_line'] if all(col in df_cards.columns for col in ['id', 'name', 'type_line']) else df_cards.columns[:3]
    print(df_cards[display_cols].head(3))
else:
    print("⚠️  No card data loaded")
# Out:
# Getting card database statistics...
# 📊 Found 110,031 total cards in database
# 📥 Loading sample cards for analysis...
# ✅ Successfully loaded 100 sample cards
#
# Sample DataFrame shape: (100, 80)
# Total cards in database: 110,031
# Sample columns: ['_id', 'object', 'id', 'oracle_id', 'multiverse_ids', 'mtgo_id', 'arena_id', 'tcgplayer_id', 'cardmarket_id', 'name', 'lang', 'released_at', 'uri', 'scryfall_uri', 'layout', 'highres_image', 'image_status', 'image_uris', 'mana_cost', 'cmc', 'type_line', 'oracle_text', 'colors', 'color_identity', 'keywords', 'produced_mana', 'legalities', 'games', 'reserved', 'game_changer', 'foil', 'nonfoil', 'finishes', 'oversized', 'promo', 'reprint', 'variation', 'set_id', 'set', 'set_name', 'set_type', 'set_uri', 'set_search_uri', 'scryfall_set_uri', 'rulings_uri', 'prints_search_uri', 'collector_number', 'digital', 'rarity', 'card_back_id', 'artist', 'artist_ids', 'illustration_id', 'border_color', 'frame', 'full_art', 'textless', 'booster', 'story_spotlight', 'prices', 'related_uris', 'purchase_uris', 'day_uploaded', 'pricing', 'last_price_update', 'mtgo_foil_id', 'power', 'toughness', 'flavor_text', 'edhrec_rank', 'penny_rank', 'all_parts', 'promo_types', 'security_stamp', 'card_faces', 'preview', 'watermark', 'frame_effects', 'loyalty', 'printed_name']
#
# === SAMPLE CARDS DATA ===
#                                      id           name               type_line
# 0  0000419b-0bba-4488-8f7a-6194544ce91e         Forest     Basic Land — Forest
# 1  0000579f-7b35-4ed3-b44c-db2a538066fe    Fury Sliver       Creature — Sliver
# 2  00006596-1166-4a79-8443-ca9f82e6db4e  Kor Outfitter  Creature — Kor Soldier

# %% [markdown]
# ### Get pricing data

# %%
# Load pricing data  
print("Loading pricing data from database...")
pricing_collection = get_collection(client, database_name, "card_pricing_daily")
all_pricing = list(pricing_collection.find({}))
print(f"✅ Loaded {len(all_pricing)} pricing records from 'card_pricing_daily' collection")

df_pricing = pd.DataFrame(all_pricing)
print(f"Pricing DataFrame shape: {df_pricing.shape}")
print(f"Pricing columns: {list(df_pricing.columns)}")

print("\n=== SAMPLE PRICING DATA ===")
print(df_pricing.head(3))
# Out:
# Loading pricing data from database...
# ✅ Loaded 792 pricing records from 'card_pricing_daily' collection
# Pricing DataFrame shape: (792, 14)
# Pricing columns: ['_id', 'card_uuid', 'card_name', 'set_code', 'scryfall_id', 'price_usd', 'price_type', 'source', 'tcgplayer_id', 'cardmarket_id', 'date', 'timestamp', 'created_at', 'collected_at']
#
# === SAMPLE PRICING DATA ===
#                         _id                 card_uuid  \
# 0  693c9a8390c74c6f72124891  68d04c8859fb4c414fdabc7e
# 1  693c9a8390c74c6f72124892  68d04c8859fb4c414fdabc7e
# 2  693c9a8390c74c6f72124893  68d04c9e59fb4c414fdabe5e
#
#                    card_name set_code                           scryfall_id  \
# 0              Jolly Gerbils      blb  0eab51d6-ba17-4a8c-8834-25db363f2b6b
# 1              Jolly Gerbils      blb  0eab51d6-ba17-4a8c-8834-25db363f2b6b
# 2  Beza, the Bounding Spring      blb  0fc98b72-d268-4ce5-93b4-57c812a24eff
#
#    price_usd price_type             source  tcgplayer_id  cardmarket_id  \
# 0       0.03        usd       scryfall_usd        559994       779260.0
# 1       0.08   usd_foil  scryfall_usd_foil        559994       779260.0
# 2       9.59        usd       scryfall_usd        558423       778056.0
#
#          date                         timestamp              created_at  \
# 0  2025-12-12  2025-12-12T22:43:07.906849+00:00 2025-12-12 22:43:07.906
# 1  2025-12-12  2025-12-12T22:43:07.906849+00:00 2025-12-12 22:43:07.906
# 2  2025-12-12  2025-12-12T22:43:07.906849+00:00 2025-12-12 22:43:07.906
#
#   collected_at
# 0          NaT
# 1          NaT
# 2          NaT

# %% [markdown]
# ## 4. Current Pricing Coverage Analysis

# %%
# Analyze current pricing coverage
print("=== PRICING COVERAGE ANALYSIS ===")
print(f"Total cards: {len(df_cards):,}")
print(f"Total pricing records: {len(df_pricing):,}")

# Check for pricing data linkage
if 'scryfall_id' in df_pricing.columns:
    unique_cards_with_pricing = df_pricing['scryfall_id'].nunique()
    print(f"Unique cards with pricing (by scryfall_id): {unique_cards_with_pricing:,}")
    
    # Calculate coverage
    cards_without_pricing = len(df_cards) - unique_cards_with_pricing
    coverage_pct = (unique_cards_with_pricing / len(df_cards)) * 100
    
    print(f"Cards WITHOUT pricing: {cards_without_pricing:,}")
    print(f"Coverage: {coverage_pct:.2f}%")
    
    # Pricing by date analysis
    if 'date' in df_pricing.columns:
        pricing_by_date = df_pricing.groupby('date').size().sort_index(ascending=False)
        print(f"\n📅 Pricing records by date:")
        for date, count in pricing_by_date.head().items():
            print(f"   {date}: {count:,} records")
    
    # Price type analysis  
    if 'price_type' in df_pricing.columns:
        price_type_counts = df_pricing['price_type'].value_counts()
        print(f"\n💰 Price type distribution:")
        for price_type, count in price_type_counts.items():
            print(f"   {price_type}: {count:,} records")
else:
    print("⚠️  No 'scryfall_id' column found in pricing data")
    print("Available pricing columns:", list(df_pricing.columns))

# Sample card analysis
if len(df_pricing) > 0:
    print(f"\n📋 Sample pricing records structure:")
    sample_pricing = df_pricing.iloc[0]
    for key, value in sample_pricing.items():
        print(f"   {key}: {value} ({type(value).__name__})")
# Out:
# === PRICING COVERAGE ANALYSIS ===
# Total cards: 100
# Total pricing records: 792
# Unique cards with pricing (by scryfall_id): 397
# Cards WITHOUT pricing: -297
# Coverage: 397.00%
#
# 📅 Pricing records by date:
#    2025-12-13: 25 records
#    2025-12-12: 767 records
#
# 💰 Price type distribution:
#    usd: 405 records
#    usd_foil: 387 records
#
# 📋 Sample pricing records structure:
#    _id: 693c9a8390c74c6f72124891 (ObjectId)
#    card_uuid: 68d04c8859fb4c414fdabc7e (str)
#    card_name: Jolly Gerbils (str)
#    set_code: blb (str)
#    scryfall_id: 0eab51d6-ba17-4a8c-8834-25db363f2b6b (str)
#    price_usd: 0.03 (float64)
#    price_type: usd (str)
#    source: scryfall_usd (str)
#    tcgplayer_id: 559994 (int64)
#    cardmarket_id: 779260.0 (float64)
#    date: 2025-12-12 (str)
#    timestamp: 2025-12-12T22:43:07.906849+00:00 (str)
#    created_at: 2025-12-12 22:43:07.906000 (Timestamp)
#    collected_at: NaT (NaTType)

# %% [markdown]
# ## 5. Bulk Pricing Collection System

# %%
class ScryfallBulkCollector:
    """
    Efficient bulk pricing collection using Scryfall's /cards/collection endpoint
    Handles up to 75 cards per request with comprehensive price data extraction
    """
    
    def __init__(self, rate_limit_delay=0.1):
        self.base_url = "https://api.scryfall.com/cards/collection"
        self.batch_size = 75  # Scryfall's limit
        self.rate_limit_delay = rate_limit_delay
        self.session = requests.Session()
        self.session.headers.update({
            'Content-Type': 'application/json',
            'User-Agent': 'MTGEcoRec/2.0'
        })
        
    def create_identifiers(self, cards_list):
        """Convert MongoDB card documents to Scryfall identifiers"""
        return [{'id': card['id']} for card in cards_list]
    
    def batch_identifiers(self, identifiers):
        """Split identifiers into batches of 75"""
        for i in range(0, len(identifiers), self.batch_size):
            yield identifiers[i:i + self.batch_size]
    
    def fetch_batch_pricing(self, identifiers_batch):
        """Fetch pricing for a batch of card identifiers"""
        try:
            payload = {'identifiers': identifiers_batch}
            response = self.session.post(self.base_url, json=payload, timeout=30)
            
            if response.status_code == 200:
                return response.json()
            else:
                logger.error(f"API Error: {response.status_code} - {response.text}")
                return None
                
        except Exception as e:
            logger.error(f"Request failed: {e}")
            return None
    
    def extract_pricing_data(self, card_data, target_date=None):
        """Extract all available pricing information from Scryfall card data"""
        if target_date is None:
            target_date = date.today().isoformat()
            
        pricing_records = []
        card_id = card_data.get('id')
        card_name = card_data.get('name', 'Unknown')
        prices = card_data.get('prices', {})
        
        # All available price types
        price_mappings = {
            'usd': 'usd',
            'usd_foil': 'usd_foil', 
            'usd_etched': 'usd_etched',
            'eur': 'eur',
            'eur_foil': 'eur_foil',
            'tix': 'tix'  # MTGO tickets
        }
        
        for price_key, price_type in price_mappings.items():
            price_value = prices.get(price_key)
            
            if price_value and price_value != "":
                try:
                    price_float = float(price_value)
                    
                    record = {
                        'card_name': card_name,
                        'scryfall_id': card_id,
                        'date': target_date,
                        'price_type': price_type,
                        'price_value': price_float,
                        'currency': price_key.split('_')[0],  # usd, eur, tix
                        'finish': 'foil' if 'foil' in price_key else 'etched' if 'etched' in price_key else 'nonfoil',
                        'tcgplayer_id': card_data.get('tcgplayer_id'),
                        'cardmarket_id': card_data.get('cardmarket_id'),
                        'collected_at': datetime.now(),
                        'source': 'scryfall_bulk'
                    }
                    
                    pricing_records.append(record)
                    
                except (ValueError, TypeError):
                    continue
        
        return pricing_records
    
    def collect_pricing_for_cards(self, cards_list, target_date=None):
        """Main method to collect pricing for a list of cards"""
        if target_date is None:
            target_date = date.today().isoformat()
            
        identifiers = self.create_identifiers(cards_list)
        all_pricing_records = []
        
        logger.info(f"Starting bulk collection for {len(identifiers)} cards")
        
        for batch_num, batch in enumerate(self.batch_identifiers(identifiers), 1):
            logger.info(f"Processing batch {batch_num} ({len(batch)} cards)")
            
            # Fetch batch data
            batch_response = self.fetch_batch_pricing(batch)
            
            if batch_response and 'data' in batch_response:
                # Process each card in the batch
                for card_data in batch_response['data']:
                    pricing_records = self.extract_pricing_data(card_data, target_date)
                    all_pricing_records.extend(pricing_records)
            
            # Rate limiting
            time.sleep(self.rate_limit_delay)
        
        logger.info(f"Collection complete: {len(all_pricing_records)} pricing records")
        return all_pricing_records

# Initialize collector
collector = ScryfallBulkCollector()
print("🚀 Bulk collector initialized and ready!")
# Out:
# 🚀 Bulk collector initialized and ready!

# %% [markdown]
# ## 4. Test with Sample Data

# %%
# Test with a small sample from BLB set
sample_cards = list(cards_collection.find({'set': 'blb'}).limit(10))
print(f"Testing with {len(sample_cards)} cards from BLB set")

# Collect pricing data
test_pricing = collector.collect_pricing_for_cards(sample_cards)

print(f"\n📊 Test Results:")
print(f"   Cards processed: {len(sample_cards)}")
print(f"   Pricing records: {len(test_pricing)}")
print(f"   Avg records per card: {len(test_pricing)/len(sample_cards):.1f}")

# Show sample records
if test_pricing:
    print(f"\n📋 Sample pricing record:")
    sample = test_pricing[0]
    for key, value in sample.items():
        if key == 'collected_at':
            print(f"   {key}: {value.isoformat()}")
        else:
            print(f"   {key}: {value}")
# Out:
# 2025-12-12 23:52:18,509 - INFO - Starting bulk collection for 10 cards
# 2025-12-12 23:52:18,510 - INFO - Processing batch 1 (10 cards)
# Testing with 10 cards from BLB set
# 2025-12-12 23:52:18,925 - INFO - Collection complete: 48 pricing records
# 📊 Test Results:
#    Cards processed: 10
#    Pricing records: 48
#    Avg records per card: 4.8
#
# 📋 Sample pricing record:
#    card_name: Forest
#    scryfall_id: 0000419b-0bba-4488-8f7a-6194544ce91e
#    date: 2025-12-12
#    price_type: usd
#    price_value: 0.22
#    currency: usd
#    finish: nonfoil
#    tcgplayer_id: 558404
#    cardmarket_id: 777725
#    collected_at: 2025-12-12T23:52:18.824974
#    source: scryfall_bulk

# %% [markdown]
# ## 6. Larger Scale Test
#
# Let's test with 150 cards (2 full batches) to validate performance at scale.

# %%
# Test with 150 cards (2 full batches of 75 each) to validate scale performance
print("🔍 Starting larger scale test...")
print("=" * 50)

# Get 150 cards from different sets to test diversity
test_cards_mixed = []

# Get cards from multiple sets for diverse testing
sets_to_test = ['blb', 'dsk', 'otj', 'mkm', 'lci']  # Various recent sets
cards_per_set = 30  # 30 cards from each set = 150 total

for set_code in sets_to_test:
    set_cards = list(cards_collection.find({'set': set_code}).limit(cards_per_set))
    test_cards_mixed.extend(set_cards)
    print(f"📦 Collected {len(set_cards)} cards from {set_code.upper()} set")

print(f"\n🎯 Total test cards: {len(test_cards_mixed)}")
print(f"📊 Expected batches: {(len(test_cards_mixed) + 74) // 75}")  # Ceiling division

# Record start time for performance analysis
import time
start_time = time.time()

# Run the bulk collection
print(f"\n🚀 Starting bulk collection test...")
large_test_pricing = collector.collect_pricing_for_cards(test_cards_mixed)

# Calculate performance metrics
end_time = time.time()
total_time = end_time - start_time
cards_per_second = len(test_cards_mixed) / total_time if total_time > 0 else 0
records_per_second = len(large_test_pricing) / total_time if total_time > 0 else 0

print(f"\n📈 LARGE SCALE TEST RESULTS")
print("=" * 50)
print(f"   Cards processed: {len(test_cards_mixed):,}")
print(f"   Pricing records: {len(large_test_pricing):,}")
print(f"   Avg records per card: {len(large_test_pricing)/len(test_cards_mixed):.1f}")
print(f"   Total processing time: {total_time:.1f} seconds")
print(f"   Cards per second: {cards_per_second:.1f}")
print(f"   Records per second: {records_per_second:.1f}")
print(f"   Efficiency vs individual API: ~{75:.0f}x faster")

# Analyze price type distribution
if large_test_pricing:
    price_types = {}
    currencies = {}
    
    for record in large_test_pricing:
        price_type = record.get('price_type', 'unknown')
        currency = record.get('currency', 'unknown')
        
        price_types[price_type] = price_types.get(price_type, 0) + 1
        currencies[currency] = currencies.get(currency, 0) + 1
    
    print(f"\n💰 Price Type Distribution:")
    for ptype, count in sorted(price_types.items(), key=lambda x: x[1], reverse=True):
        print(f"   {ptype}: {count:,} records ({count/len(large_test_pricing)*100:.1f}%)")
    
    print(f"\n💱 Currency Distribution:")
    for curr, count in sorted(currencies.items(), key=lambda x: x[1], reverse=True):
        print(f"   {curr}: {count:,} records ({count/len(large_test_pricing)*100:.1f}%)")
    
    # Show sample of collected data
    print(f"\n📋 Sample records from different price types:")
    seen_types = set()
    for record in large_test_pricing:
        ptype = record.get('price_type')
        if ptype not in seen_types and len(seen_types) < 3:
            seen_types.add(ptype)
            print(f"   {record['card_name']} - ${record['price_value']} ({ptype})")

print(f"\n✅ Large scale test completed successfully!")

# %% [markdown]
# ## 5. Production Pipeline Function

# %%
def run_daily_pricing_pipeline(target_date=None, batch_size=1000, skip_existing=True):
    """
    Production-ready daily pricing pipeline
    
    Args:
        target_date: Date string (YYYY-MM-DD) or None for today
        batch_size: Number of cards to process per database batch
        skip_existing: Skip cards that already have pricing for target_date
    
    Returns:
        dict: Summary statistics
    """
    if target_date is None:
        target_date = date.today().isoformat()
    
    logger.info(f"Starting daily pricing pipeline for {target_date}")
    
    # Get cards that need pricing
    if skip_existing:
        # Get cards without pricing for this date
        existing_card_ids = set(
            record['scryfall_id'] 
            for record in pricing_collection.find(
                {'date': target_date}, 
                {'scryfall_id': 1}
            )
        )
        
        cards_query = {'id': {'$nin': list(existing_card_ids)}}
        logger.info(f"Skipping {len(existing_card_ids)} cards with existing pricing")
    else:
        cards_query = {}
    
    total_cards_needed = cards_collection.count_documents(cards_query)
    logger.info(f"Cards needing pricing: {total_cards_needed:,}")
    
    if total_cards_needed == 0:
        logger.info("No cards need pricing collection")
        return {'status': 'complete', 'cards_processed': 0, 'records_created': 0}
    
    # Process in batches
    total_records = 0
    cards_processed = 0
    
    cards_cursor = cards_collection.find(cards_query).batch_size(batch_size)
    current_batch = []
    
    for card in cards_cursor:
        current_batch.append(card)
        
        if len(current_batch) >= batch_size:
            # Process batch
            batch_records = collector.collect_pricing_for_cards(current_batch, target_date)
            
            # Insert to database
            if batch_records:
                pricing_collection.insert_many(batch_records)
                total_records += len(batch_records)
            
            cards_processed += len(current_batch)
            logger.info(f"Progress: {cards_processed:,}/{total_cards_needed:,} cards ({cards_processed/total_cards_needed*100:.1f}%)")
            
            current_batch = []
    
    # Process final batch
    if current_batch:
        batch_records = collector.collect_pricing_for_cards(current_batch, target_date)
        if batch_records:
            pricing_collection.insert_many(batch_records)
            total_records += len(batch_records)
        cards_processed += len(current_batch)
    
    logger.info(f"Pipeline complete: {cards_processed:,} cards, {total_records:,} records")
    
    return {
        'status': 'complete',
        'date': target_date,
        'cards_processed': cards_processed,
        'records_created': total_records,
        'avg_records_per_card': total_records / cards_processed if cards_processed > 0 else 0
    }

print("✅ Production pipeline function ready")
# Out:
# ✅ Production pipeline function ready

# %% [markdown]
# ## 🚀 Production Pipeline Execution
#
# Starting full production pipeline to collect pricing for all remaining cards.

# %%
# 🚀 PRODUCTION PIPELINE EXECUTION
# This will collect pricing for all cards that don't have today's pricing data

print("🔥 STARTING PRODUCTION PRICING PIPELINE")
print("=" * 60)
print(f"📅 Target date: {date.today().isoformat()}")
print(f"🎯 Expected cards to process: ~109,634 (total - cards with existing pricing)")
print(f"⚡ Batch size: 75 cards per API call (~1,467 total API calls)")
print(f"⏱️  Estimated time: ~15-20 minutes (with 0.1s rate limiting)")
print("=" * 60)

# Run the production pipeline
print("\\n🚀 Starting pipeline execution...")
result = run_daily_pricing_pipeline(
    target_date='2025-12-13',  # Today's date
    batch_size=1000,           # Cards per database batch 
    skip_existing=True         # Skip cards that already have pricing for today
)

print("\\n" + "=" * 60)
print("🎉 PRODUCTION PIPELINE COMPLETED!")
print("=" * 60)
print(f"📊 Final Results:")
for key, value in result.items():
    if isinstance(value, (int, float)):
        if key in ['cards_processed', 'records_created']:
            print(f"   {key}: {value:,}")
        else:
            print(f"   {key}: {value}")
    else:
        print(f"   {key}: {value}")
        
# Show updated coverage statistics
print(f"\\n📈 Updated Database Statistics:")
total_cards_after = cards_collection.count_documents({})
total_pricing_after = pricing_collection.count_documents({})
unique_cards_with_pricing_after = len(pricing_collection.distinct('scryfall_id'))

print(f"   Total cards in database: {total_cards_after:,}")
print(f"   Total pricing records: {total_pricing_after:,}")
print(f"   Unique cards with pricing: {unique_cards_with_pricing_after:,}")
print(f"   Coverage: {(unique_cards_with_pricing_after/total_cards_after*100):.2f}%")
print(f"\\n✅ Production pipeline execution complete!")
# Out:
# 2025-12-13 00:01:01,007 - INFO - Starting daily pricing pipeline for 2025-12-13
# 🔥 STARTING PRODUCTION PRICING PIPELINE
# ============================================================
# 📅 Target date: 2025-12-13
# 🎯 Expected cards to process: ~109,634 (total - cards with existing pricing)
# ⚡ Batch size: 75 cards per API call (~1,467 total API calls)
# ⏱️  Estimated time: ~15-20 minutes (with 0.1s rate limiting)
# ============================================================
# \n🚀 Starting pipeline execution...
# 2025-12-13 00:01:01,502 - INFO - Skipping 25 cards with existing pricing
# 2025-12-13 00:01:02,299 - INFO - Cards needing pricing: 110,006
# 2025-12-13 00:01:03,485 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:01:03,486 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:01:04,525 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:01:05,014 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:01:05,819 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:01:06,395 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:01:07,040 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:01:07,485 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:01:08,096 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:01:08,756 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:01:09,240 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:01:09,632 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:01:10,474 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:01:11,425 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:01:11,834 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:01:12,365 - INFO - Collection complete: 2938 pricing records
# 2025-12-13 00:01:24,435 - INFO - Progress: 1,000/110,006 cards (0.9%)
# 2025-12-13 00:01:25,066 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:01:25,067 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:01:25,749 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:01:26,472 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:01:27,077 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:01:27,754 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:01:28,394 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:01:28,911 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:01:29,476 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:01:30,085 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:01:30,839 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:01:31,408 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:01:31,815 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:01:32,274 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:01:32,755 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:01:33,024 - INFO - Collection complete: 2925 pricing records
# 2025-12-13 00:01:45,007 - INFO - Progress: 2,000/110,006 cards (1.8%)
# 2025-12-13 00:01:45,713 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:01:45,714 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:01:47,602 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:01:48,846 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:01:49,623 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:01:50,314 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:01:50,732 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:01:51,489 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:01:52,040 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:01:52,739 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:01:53,486 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:01:54,911 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:01:57,184 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:01:57,615 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:01:59,377 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:01:59,701 - INFO - Collection complete: 2848 pricing records
# 2025-12-13 00:02:11,186 - INFO - Progress: 3,000/110,006 cards (2.7%)
# 2025-12-13 00:02:11,942 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:02:11,943 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:02:13,683 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:02:14,497 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:02:15,177 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:02:15,806 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:02:16,391 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:02:17,109 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:02:17,704 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:02:18,702 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:02:21,439 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:02:22,632 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:02:24,244 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:02:25,118 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:02:26,579 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:02:26,851 - INFO - Collection complete: 2803 pricing records
# 2025-12-13 00:02:38,274 - INFO - Progress: 4,000/110,006 cards (3.6%)
# 2025-12-13 00:02:39,063 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:02:39,064 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:02:39,921 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:02:40,865 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:02:41,427 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:02:42,281 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:02:43,356 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:02:44,658 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:02:45,665 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:02:46,394 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:02:47,734 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:02:48,502 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:02:49,476 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:02:51,054 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:02:52,000 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:02:52,310 - INFO - Collection complete: 2857 pricing records
# 2025-12-13 00:03:04,032 - INFO - Progress: 5,000/110,006 cards (4.5%)
# 2025-12-13 00:03:04,843 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:03:04,844 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:03:05,620 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:03:06,078 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:03:06,699 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:03:07,498 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:03:08,273 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:03:08,989 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:03:09,776 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:03:10,673 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:03:11,476 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:03:12,012 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:03:12,515 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:03:12,869 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:03:13,279 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:03:13,571 - INFO - Collection complete: 2928 pricing records
# 2025-12-13 00:03:25,562 - INFO - Progress: 6,000/110,006 cards (5.5%)
# 2025-12-13 00:03:26,156 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:03:26,157 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:03:26,891 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:03:28,262 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:03:29,278 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:03:29,941 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:03:30,635 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:03:31,282 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:03:31,945 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:03:32,454 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:03:33,071 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:03:34,241 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:03:34,980 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:03:35,770 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:03:36,600 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:03:36,930 - INFO - Collection complete: 2996 pricing records
# 2025-12-13 00:03:48,854 - INFO - Progress: 7,000/110,006 cards (6.4%)
# 2025-12-13 00:03:49,527 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:03:49,528 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:03:50,301 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:03:50,874 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:03:51,327 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:03:51,828 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:03:52,475 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:03:53,026 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:03:53,398 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:03:54,106 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:03:54,767 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:03:55,446 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:03:56,169 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:03:56,584 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:03:57,160 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:03:57,518 - INFO - Collection complete: 2964 pricing records
# 2025-12-13 00:04:09,537 - INFO - Progress: 8,000/110,006 cards (7.3%)
# 2025-12-13 00:04:10,226 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:04:10,227 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:04:12,319 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:04:13,189 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:04:14,476 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:04:14,874 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:04:15,366 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:04:15,877 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:04:16,258 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:04:16,860 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:04:17,483 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:04:18,268 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:04:18,995 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:04:19,567 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:04:20,253 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:04:20,619 - INFO - Collection complete: 3017 pricing records
# 2025-12-13 00:04:32,923 - INFO - Progress: 9,000/110,006 cards (8.2%)
# 2025-12-13 00:04:51,173 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:04:51,174 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:04:51,678 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:04:53,931 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:04:54,567 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:04:55,163 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:04:55,832 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:04:56,517 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:04:57,533 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:04:58,419 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:04:59,336 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:04:59,781 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:05:00,222 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:05:01,045 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:05:01,805 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:05:02,082 - INFO - Collection complete: 2866 pricing records
# 2025-12-13 00:05:13,730 - INFO - Progress: 10,000/110,006 cards (9.1%)
# 2025-12-13 00:05:14,518 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:05:14,519 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:05:15,293 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:05:15,857 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:05:16,586 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:05:17,153 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:05:17,757 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:05:18,466 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:05:19,081 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:05:19,794 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:05:20,621 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:05:21,421 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:05:21,881 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:05:22,335 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:05:23,314 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:05:23,598 - INFO - Collection complete: 2810 pricing records
# 2025-12-13 00:05:35,011 - INFO - Progress: 11,000/110,006 cards (10.0%)
# 2025-12-13 00:05:35,744 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:05:35,745 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:05:36,434 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:05:36,992 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:05:37,565 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:05:38,242 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:05:38,841 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:05:39,274 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:05:39,721 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:05:40,415 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:05:40,814 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:05:41,619 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:05:42,326 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:05:42,861 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:05:43,412 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:05:43,675 - INFO - Collection complete: 2925 pricing records
# 2025-12-13 00:05:55,609 - INFO - Progress: 12,000/110,006 cards (10.9%)
# 2025-12-13 00:05:56,372 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:05:56,374 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:05:57,121 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:05:57,972 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:05:58,709 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:05:59,407 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:06:00,729 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:06:01,323 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:06:01,919 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:06:02,467 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:06:03,017 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:06:04,024 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:06:05,262 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:06:06,380 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:06:07,182 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:06:07,577 - INFO - Collection complete: 2947 pricing records
# 2025-12-13 00:06:19,654 - INFO - Progress: 13,000/110,006 cards (11.8%)
# 2025-12-13 00:06:20,335 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:06:20,336 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:06:21,016 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:06:21,466 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:06:22,081 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:06:22,465 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:06:22,795 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:06:23,163 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:06:23,631 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:06:24,063 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:06:24,682 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:06:25,240 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:06:25,583 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:06:26,301 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:06:26,922 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:06:27,252 - INFO - Collection complete: 2832 pricing records
# 2025-12-13 00:06:38,829 - INFO - Progress: 14,000/110,006 cards (12.7%)
# 2025-12-13 00:06:39,552 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:06:39,553 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:06:40,552 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:06:40,916 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:06:41,627 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:06:42,192 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:06:43,592 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:06:44,283 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:06:44,861 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:06:45,504 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:06:46,875 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:06:47,411 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:06:47,943 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:06:48,453 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:06:48,834 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:06:49,096 - INFO - Collection complete: 2897 pricing records
# 2025-12-13 00:07:00,952 - INFO - Progress: 15,000/110,006 cards (13.6%)
# 2025-12-13 00:07:01,604 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:07:01,604 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:07:02,181 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:07:02,614 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:07:03,387 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:07:03,799 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:07:04,346 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:07:04,883 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:07:05,321 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:07:05,811 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:07:06,395 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:07:06,895 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:07:07,506 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:07:08,114 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:07:08,577 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:07:08,939 - INFO - Collection complete: 2879 pricing records
# 2025-12-13 00:07:20,552 - INFO - Progress: 16,000/110,006 cards (14.5%)
# 2025-12-13 00:07:21,199 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:07:21,200 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:07:21,728 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:07:22,497 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:07:23,083 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:07:23,454 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:07:23,947 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:07:24,614 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:07:25,165 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:07:25,822 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:07:26,419 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:07:26,865 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:07:27,235 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:07:27,851 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:07:28,247 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:07:28,533 - INFO - Collection complete: 2859 pricing records
# 2025-12-13 00:07:40,104 - INFO - Progress: 17,000/110,006 cards (15.5%)
# 2025-12-13 00:07:40,778 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:07:40,779 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:07:41,791 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:07:42,378 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:07:43,144 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:07:43,847 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:07:44,393 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:07:45,027 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:07:45,764 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:07:46,194 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:07:46,690 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:07:47,062 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:07:47,743 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:07:48,210 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:07:48,891 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:07:49,258 - INFO - Collection complete: 2913 pricing records
# 2025-12-13 00:08:01,125 - INFO - Progress: 18,000/110,006 cards (16.4%)
# 2025-12-13 00:08:01,716 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:08:01,717 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:08:02,712 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:08:03,651 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:08:04,345 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:08:05,518 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:08:06,257 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:08:07,313 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:08:07,715 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:08:08,195 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:08:08,816 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:08:09,996 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:08:10,586 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:08:11,294 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:08:12,039 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:08:12,303 - INFO - Collection complete: 2911 pricing records
# 2025-12-13 00:08:23,675 - INFO - Progress: 19,000/110,006 cards (17.3%)
# 2025-12-13 00:08:24,264 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:08:24,265 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:08:25,109 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:08:25,972 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:08:26,662 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:08:27,707 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:08:28,234 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:08:28,653 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:08:29,151 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:08:29,544 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:08:30,002 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:08:30,414 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:08:30,878 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:08:31,428 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:08:32,038 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:08:32,457 - INFO - Collection complete: 2965 pricing records
# 2025-12-13 00:08:44,441 - INFO - Progress: 20,000/110,006 cards (18.2%)
# 2025-12-13 00:08:45,082 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:08:45,083 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:08:45,640 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:08:46,275 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:08:46,841 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:08:47,554 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:08:48,081 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:08:48,623 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:08:49,034 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:08:49,653 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:08:50,273 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:08:51,177 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:08:51,815 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:08:52,344 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:08:52,886 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:08:53,265 - INFO - Collection complete: 2921 pricing records
# 2025-12-13 00:09:05,182 - INFO - Progress: 21,000/110,006 cards (19.1%)
# 2025-12-13 00:09:05,900 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:09:05,901 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:09:06,519 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:09:07,268 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:09:07,943 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:09:09,091 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:09:09,989 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:09:10,325 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:09:11,064 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:09:11,737 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:09:13,128 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:09:14,331 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:09:15,382 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:09:16,037 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:09:16,749 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:09:17,111 - INFO - Collection complete: 2926 pricing records
# 2025-12-13 00:09:29,071 - INFO - Progress: 22,000/110,006 cards (20.0%)
# 2025-12-13 00:09:29,672 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:09:29,673 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:09:30,237 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:09:31,454 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:09:33,132 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:09:34,345 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:09:35,485 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:09:36,419 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:09:37,321 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:09:38,199 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:09:38,974 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:09:39,577 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:09:41,151 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:09:41,677 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:09:42,436 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:09:43,138 - INFO - Collection complete: 2877 pricing records
# 2025-12-13 00:09:54,724 - INFO - Progress: 23,000/110,006 cards (20.9%)
# 2025-12-13 00:09:55,288 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:09:55,288 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:09:55,835 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:09:56,175 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:09:56,761 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:09:57,912 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:09:58,685 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:09:59,271 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:10:00,068 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:10:00,477 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:10:01,398 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:10:02,488 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:10:02,932 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:10:03,484 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:10:03,946 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:10:04,331 - INFO - Collection complete: 2889 pricing records
# 2025-12-13 00:10:16,055 - INFO - Progress: 24,000/110,006 cards (21.8%)
# 2025-12-13 00:10:16,709 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:10:16,710 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:10:17,738 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:10:18,730 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:10:19,633 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:10:20,752 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:10:21,468 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:10:22,428 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:10:23,111 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:10:23,536 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:10:24,146 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:10:24,782 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:10:25,466 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:10:26,491 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:10:27,218 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:10:27,693 - INFO - Collection complete: 2897 pricing records
# 2025-12-13 00:10:39,444 - INFO - Progress: 25,000/110,006 cards (22.7%)
# 2025-12-13 00:10:40,327 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:10:40,327 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:10:41,130 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:10:41,896 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:10:42,778 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:10:43,616 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:10:44,356 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:10:45,956 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:10:47,699 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:10:48,531 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:10:49,489 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:10:50,269 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:10:50,833 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:10:51,465 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:10:53,424 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:10:53,950 - INFO - Collection complete: 2856 pricing records
# 2025-12-13 00:11:05,636 - INFO - Progress: 26,000/110,006 cards (23.6%)
# 2025-12-13 00:11:06,257 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:11:06,258 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:11:06,915 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:11:07,888 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:11:09,214 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:11:10,055 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:11:11,063 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:11:12,183 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:11:13,302 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:11:14,001 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:11:16,108 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:11:16,937 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:11:19,633 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:11:21,909 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:11:23,618 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:11:24,084 - INFO - Collection complete: 2967 pricing records
# 2025-12-13 00:11:36,141 - INFO - Progress: 27,000/110,006 cards (24.5%)
# 2025-12-13 00:11:36,850 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:11:36,851 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:11:37,808 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:11:38,383 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:11:38,782 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:11:39,411 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:11:41,124 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:11:42,531 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:11:45,221 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:11:45,799 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:11:46,360 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:11:47,185 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:11:48,174 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:11:49,173 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:11:50,166 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:11:50,559 - INFO - Collection complete: 2835 pricing records
# 2025-12-13 00:12:02,148 - INFO - Progress: 28,000/110,006 cards (25.5%)
# 2025-12-13 00:12:02,822 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:12:02,823 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:12:03,678 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:12:05,585 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:12:07,718 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:12:08,657 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:12:09,262 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:12:10,299 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:12:11,072 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:12:11,749 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:12:12,133 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:12:13,417 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:12:14,076 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:12:15,468 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:12:15,890 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:12:16,226 - INFO - Collection complete: 2967 pricing records
# 2025-12-13 00:12:28,300 - INFO - Progress: 29,000/110,006 cards (26.4%)
# 2025-12-13 00:12:28,903 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:12:28,903 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:12:30,029 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:12:31,614 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:12:32,049 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:12:32,553 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:12:33,403 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:12:34,004 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:12:34,637 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:12:35,223 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:12:36,040 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:12:36,649 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:12:37,566 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:12:38,324 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:12:38,874 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:12:39,156 - INFO - Collection complete: 2892 pricing records
# 2025-12-13 00:12:50,909 - INFO - Progress: 30,000/110,006 cards (27.3%)
# 2025-12-13 00:12:51,594 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:12:51,596 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:12:52,325 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:12:52,867 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:12:53,755 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:12:54,664 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:12:55,085 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:12:55,953 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:12:56,668 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:12:57,276 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:12:57,718 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:12:58,138 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:12:58,527 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:12:59,358 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:12:59,762 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:13:00,021 - INFO - Collection complete: 2864 pricing records
# 2025-12-13 00:13:11,593 - INFO - Progress: 31,000/110,006 cards (28.2%)
# 2025-12-13 00:13:12,228 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:13:12,230 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:13:12,811 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:13:13,433 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:13:13,948 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:13:14,365 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:13:14,933 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:13:15,435 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:13:15,814 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:13:16,330 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:13:16,717 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:13:17,254 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:13:17,716 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:13:18,300 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:13:18,959 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:13:19,253 - INFO - Collection complete: 2942 pricing records
# 2025-12-13 00:13:31,227 - INFO - Progress: 32,000/110,006 cards (29.1%)
# 2025-12-13 00:13:31,890 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:13:31,890 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:13:33,285 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:13:34,082 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:13:35,242 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:13:36,011 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:13:37,529 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:13:38,314 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:13:39,253 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:13:40,109 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:13:40,841 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:13:41,548 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:13:42,393 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:13:42,797 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:13:43,269 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:13:43,615 - INFO - Collection complete: 2971 pricing records
# 2025-12-13 00:13:55,737 - INFO - Progress: 33,000/110,006 cards (30.0%)
# 2025-12-13 00:13:56,477 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:13:56,478 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:13:57,067 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:13:57,684 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:13:58,084 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:13:58,436 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:13:58,782 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:13:59,422 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:13:59,851 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:14:00,207 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:14:00,613 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:14:01,037 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:14:01,427 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:14:02,126 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:14:02,961 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:14:03,268 - INFO - Collection complete: 2933 pricing records
# 2025-12-13 00:14:15,219 - INFO - Progress: 34,000/110,006 cards (30.9%)
# 2025-12-13 00:14:15,889 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:14:15,889 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:14:16,518 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:14:17,079 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:14:17,876 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:14:18,635 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:14:19,272 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:14:19,800 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:14:20,374 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:14:20,964 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:14:22,664 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:14:23,401 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:14:23,844 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:14:24,269 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:14:24,933 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:14:25,189 - INFO - Collection complete: 2884 pricing records
# 2025-12-13 00:14:36,946 - INFO - Progress: 35,000/110,006 cards (31.8%)
# 2025-12-13 00:14:37,640 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:14:37,641 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:14:38,383 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:14:38,799 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:14:39,562 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:14:40,244 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:14:40,940 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:14:41,666 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:14:42,259 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:14:44,293 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:14:45,817 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:14:46,528 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:14:46,955 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:14:48,466 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:14:48,891 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:14:49,188 - INFO - Collection complete: 2867 pricing records
# 2025-12-13 00:15:00,894 - INFO - Progress: 36,000/110,006 cards (32.7%)
# 2025-12-13 00:15:01,633 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:15:01,634 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:15:05,523 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:15:06,497 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:15:07,655 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:15:09,346 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:15:10,511 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:15:12,062 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:15:13,975 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:15:14,523 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:15:16,184 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:15:18,752 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:15:19,667 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:15:21,017 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:15:22,195 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:15:23,136 - INFO - Collection complete: 2996 pricing records
# 2025-12-13 00:15:35,059 - INFO - Progress: 37,000/110,006 cards (33.6%)
# 2025-12-13 00:15:35,886 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:15:35,887 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:15:36,705 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:15:37,337 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:15:38,041 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:15:38,636 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:15:39,337 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:15:39,950 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:15:41,520 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:15:42,651 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:15:43,581 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:15:44,044 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:15:44,652 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:15:45,161 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:15:45,718 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:15:46,168 - INFO - Collection complete: 2876 pricing records
# 2025-12-13 00:15:58,014 - INFO - Progress: 38,000/110,006 cards (34.5%)
# 2025-12-13 00:15:58,775 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:15:58,776 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:15:59,337 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:15:59,874 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:16:00,450 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:16:01,054 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:16:01,601 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:16:02,270 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:16:02,840 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:16:03,365 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:16:03,697 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:16:04,164 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:16:04,846 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:16:05,580 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:16:06,212 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:16:06,504 - INFO - Collection complete: 2951 pricing records
# 2025-12-13 00:16:18,504 - INFO - Progress: 39,000/110,006 cards (35.5%)
# 2025-12-13 00:16:19,171 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:16:19,173 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:16:19,986 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:16:20,639 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:16:21,407 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:16:22,318 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:16:23,336 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:16:24,144 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:16:24,730 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:16:25,782 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:16:26,721 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:16:27,266 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:16:27,959 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:16:28,792 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:16:29,476 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:16:29,750 - INFO - Collection complete: 2920 pricing records
# 2025-12-13 00:16:41,323 - INFO - Progress: 40,000/110,006 cards (36.4%)
# 2025-12-13 00:16:41,961 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:16:41,962 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:16:42,609 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:16:43,045 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:16:43,499 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:16:43,930 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:16:44,649 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:16:45,033 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:16:45,670 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:16:46,191 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:16:46,794 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:16:47,456 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:16:47,956 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:16:48,791 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:16:49,327 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:16:49,585 - INFO - Collection complete: 2948 pricing records
# 2025-12-13 00:17:01,530 - INFO - Progress: 41,000/110,006 cards (37.3%)
# 2025-12-13 00:17:02,314 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:17:02,317 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:17:03,125 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:17:03,527 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:17:04,802 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:17:05,380 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:17:06,143 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:17:06,855 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:17:07,426 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:17:07,989 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:17:08,548 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:17:09,001 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:17:09,430 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:17:09,937 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:17:10,455 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:17:10,744 - INFO - Collection complete: 2949 pricing records
# 2025-12-13 00:17:22,788 - INFO - Progress: 42,000/110,006 cards (38.2%)
# 2025-12-13 00:17:23,496 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:17:23,496 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:17:24,071 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:17:25,058 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:17:25,575 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:17:26,039 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:17:26,461 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:17:27,081 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:17:27,726 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:17:28,426 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:17:29,058 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:17:29,758 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:17:30,376 - INFO - Processing batch 12 (75 cards)
# ...
# 2025-12-13 00:36:52,407 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:36:53,568 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:36:54,702 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:36:55,626 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:36:56,632 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:36:57,354 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:36:58,158 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:36:59,035 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:36:59,938 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:37:00,678 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:37:01,000 - INFO - Collection complete: 2974 pricing records
# 2025-12-13 00:37:13,206 - INFO - Progress: 97,000/110,006 cards (88.2%)
# 2025-12-13 00:37:13,888 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:37:13,890 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:37:14,588 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:37:15,021 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:37:15,436 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:37:15,852 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:37:16,406 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:37:17,201 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:37:17,932 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:37:18,536 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:37:19,137 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:37:19,561 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:37:20,245 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:37:20,876 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:37:21,501 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:37:21,791 - INFO - Collection complete: 2939 pricing records
# 2025-12-13 00:37:33,960 - INFO - Progress: 98,000/110,006 cards (89.1%)
# 2025-12-13 00:37:34,687 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:37:34,688 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:37:35,279 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:37:35,711 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:37:36,267 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:37:36,995 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:37:37,479 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:37:37,891 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:37:38,336 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:37:38,755 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:37:39,450 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:37:40,115 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:37:40,796 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:37:41,209 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:37:41,774 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:37:42,072 - INFO - Collection complete: 2808 pricing records
# 2025-12-13 00:37:53,479 - INFO - Progress: 99,000/110,006 cards (90.0%)
# 2025-12-13 00:37:54,178 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:37:54,179 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:37:54,690 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:37:55,265 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:37:55,922 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:37:56,384 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:37:57,029 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:37:57,572 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:37:58,191 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:37:58,529 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:37:58,971 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:37:59,652 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:38:00,292 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:38:01,231 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:38:01,896 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:38:02,227 - INFO - Collection complete: 2953 pricing records
# 2025-12-13 00:38:14,307 - INFO - Progress: 100,000/110,006 cards (90.9%)
# 2025-12-13 00:38:14,978 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:38:14,979 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:38:15,831 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:38:16,447 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:38:17,229 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:38:18,001 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:38:18,515 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:38:19,538 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:38:20,355 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:38:20,866 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:38:21,264 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:38:21,782 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:38:22,258 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:38:22,891 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:38:23,542 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:38:23,797 - INFO - Collection complete: 2918 pricing records
# 2025-12-13 00:38:35,095 - INFO - Progress: 101,000/110,006 cards (91.8%)
# 2025-12-13 00:38:35,737 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:38:35,738 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:38:36,415 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:38:37,044 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:38:37,547 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:38:37,970 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:38:38,402 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:38:38,799 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:38:39,140 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:38:39,603 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:38:40,056 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:38:40,489 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:38:40,894 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:38:41,387 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:38:41,854 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:38:42,212 - INFO - Collection complete: 2850 pricing records
# 2025-12-13 00:38:53,744 - INFO - Progress: 102,000/110,006 cards (92.7%)
# 2025-12-13 00:38:54,416 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:38:54,417 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:38:55,069 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:38:55,691 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:38:56,207 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:38:56,811 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:38:57,246 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:38:57,860 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:38:58,516 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:38:58,910 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:38:59,276 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:38:59,858 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:39:00,308 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:39:00,780 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:39:01,231 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:39:01,505 - INFO - Collection complete: 2935 pricing records
# 2025-12-13 00:39:13,476 - INFO - Progress: 103,000/110,006 cards (93.6%)
# 2025-12-13 00:39:14,143 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:39:14,144 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:39:14,669 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:39:15,166 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:39:15,757 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:39:16,542 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:39:17,098 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:39:17,809 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:39:18,256 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:39:18,829 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:39:19,394 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:39:19,999 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:39:20,584 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:39:21,064 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:39:21,586 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:39:21,823 - INFO - Collection complete: 2989 pricing records
# 2025-12-13 00:39:34,112 - INFO - Progress: 104,000/110,006 cards (94.5%)
# 2025-12-13 00:39:34,790 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:39:34,790 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:39:35,327 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:39:35,776 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:39:36,276 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:39:36,740 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:39:37,137 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:39:37,582 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:39:39,947 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:39:40,489 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:39:41,183 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:39:41,650 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:39:42,346 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:39:42,793 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:39:43,344 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:39:43,609 - INFO - Collection complete: 2861 pricing records
# 2025-12-13 00:39:54,998 - INFO - Progress: 105,000/110,006 cards (95.4%)
# 2025-12-13 00:39:55,706 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:39:55,707 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:39:56,426 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:39:57,425 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:39:58,464 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:39:59,060 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:39:59,830 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:40:00,262 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:40:01,276 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:40:01,886 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:40:02,454 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:40:03,797 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:40:06,343 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:40:07,203 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:40:07,884 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:40:08,176 - INFO - Collection complete: 3002 pricing records
# 2025-12-13 00:40:20,530 - INFO - Progress: 106,000/110,006 cards (96.4%)
# 2025-12-13 00:40:22,580 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:40:22,581 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:40:23,122 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:40:24,531 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:40:24,923 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:40:25,765 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:40:26,207 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:40:26,801 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:40:27,461 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:40:28,045 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:40:29,072 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:40:29,728 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:40:30,198 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:40:30,902 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:40:31,420 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:40:31,716 - INFO - Collection complete: 3030 pricing records
# 2025-12-13 00:40:44,083 - INFO - Progress: 107,000/110,006 cards (97.3%)
# 2025-12-13 00:40:44,889 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:40:44,890 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:40:45,464 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:40:46,014 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:40:46,824 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:40:47,508 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:40:48,272 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:40:48,894 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:40:49,762 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:40:50,456 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:40:51,438 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:40:52,105 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:40:52,990 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:40:53,594 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:40:54,250 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:40:54,769 - INFO - Collection complete: 2935 pricing records
# 2025-12-13 00:41:06,728 - INFO - Progress: 108,000/110,006 cards (98.2%)
# 2025-12-13 00:41:07,416 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:41:07,417 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:41:08,170 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:41:08,709 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:41:09,486 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:41:10,574 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:41:11,247 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:41:11,962 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:41:12,609 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:41:13,206 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:41:13,720 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:41:14,226 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:41:14,853 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:41:15,449 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:41:16,074 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:41:16,444 - INFO - Collection complete: 2928 pricing records
# 2025-12-13 00:41:28,433 - INFO - Progress: 109,000/110,006 cards (99.1%)
# 2025-12-13 00:41:29,146 - INFO - Starting bulk collection for 1000 cards
# 2025-12-13 00:41:29,147 - INFO - Processing batch 1 (75 cards)
# 2025-12-13 00:41:30,126 - INFO - Processing batch 2 (75 cards)
# 2025-12-13 00:41:30,861 - INFO - Processing batch 3 (75 cards)
# 2025-12-13 00:41:32,406 - INFO - Processing batch 4 (75 cards)
# 2025-12-13 00:41:33,795 - INFO - Processing batch 5 (75 cards)
# 2025-12-13 00:41:34,535 - INFO - Processing batch 6 (75 cards)
# 2025-12-13 00:41:35,657 - INFO - Processing batch 7 (75 cards)
# 2025-12-13 00:41:36,555 - INFO - Processing batch 8 (75 cards)
# 2025-12-13 00:41:37,399 - INFO - Processing batch 9 (75 cards)
# 2025-12-13 00:41:39,346 - INFO - Processing batch 10 (75 cards)
# 2025-12-13 00:41:39,889 - INFO - Processing batch 11 (75 cards)
# 2025-12-13 00:41:40,442 - INFO - Processing batch 12 (75 cards)
# 2025-12-13 00:41:41,028 - INFO - Processing batch 13 (75 cards)
# 2025-12-13 00:41:42,107 - INFO - Processing batch 14 (25 cards)
# 2025-12-13 00:41:42,455 - INFO - Collection complete: 3029 pricing records
# 2025-12-13 00:41:54,729 - INFO - Progress: 110,000/110,006 cards (100.0%)
# 2025-12-13 00:41:54,781 - INFO - Starting bulk collection for 6 cards
# 2025-12-13 00:41:54,782 - INFO - Processing batch 1 (6 cards)
# 2025-12-13 00:41:55,325 - INFO - Collection complete: 0 pricing records
# 2025-12-13 00:41:55,328 - INFO - Pipeline complete: 110,006 cards, 320,641 records
# \n============================================================
# 🎉 PRODUCTION PIPELINE COMPLETED!
# ============================================================
# 📊 Final Results:
#    status: complete
#    date: 2025-12-13
#    cards_processed: 110,006
#    records_created: 320,641
#    avg_records_per_card: 2.9147591949530027
# \n📈 Updated Database Statistics:
#    Total cards in database: 110,031
#    Total pricing records: 321,433
#    Unique cards with pricing: 99,341
#    Coverage: 90.28%
# \n✅ Production pipeline execution complete!

# %% [markdown]
# ## 6. Analysis Functions

# %%
def analyze_pricing_coverage():
    """Analyze current pricing data coverage"""
    total_cards = cards_collection.count_documents({})
    
    # Cards with any pricing
    cards_with_pricing = len(
        pricing_collection.distinct('scryfall_id')
    )
    
    # Pricing by date
    pricing_by_date = list(pricing_collection.aggregate([
        {'$group': {'_id': '$date', 'count': {'$sum': 1}}},
        {'$sort': {'_id': -1}}
    ]))
    
    # Price type distribution
    price_types = list(pricing_collection.aggregate([
        {'$group': {'_id': '$price_type', 'count': {'$sum': 1}}},
        {'$sort': {'count': -1}}
    ]))
    
    print("📊 PRICING COVERAGE ANALYSIS")
    print("=" * 40)
    print(f"Total Cards: {total_cards:,}")
    print(f"Cards with Pricing: {cards_with_pricing:,}")
    print(f"Coverage: {(cards_with_pricing/total_cards*100):.2f}%")
    print()
    
    print("📅 Recent Pricing by Date:")
    for item in pricing_by_date[:5]:
        date_str = item['_id'] or 'Unknown'
        count = item['count']
        print(f"   {date_str}: {count:,} records")
    
    print()
    print("💰 Price Types:")
    for item in price_types:
        print(f"   {item['_id']}: {item['count']:,} records")

def get_pricing_summary_for_set(set_code, limit=10):
    """Get pricing summary for a specific set"""
    # Get cards from set with pricing
    pipeline = [
        {'$match': {'set': set_code.lower()}},
        {'$lookup': {
            'from': 'card_pricing_daily',
            'localField': 'id',
            'foreignField': 'scryfall_id',
            'as': 'pricing'
        }},
        {'$match': {'pricing': {'$ne': []}}},
        {'$limit': limit}
    ]
    
    results = list(cards_collection.aggregate(pipeline))
    
    print(f"🎯 PRICING SUMMARY FOR {set_code.upper()}")
    print("=" * 40)
    print(f"Cards found: {len(results)}")
    print()
    
    for card in results[:5]:
        name = card['name']
        rarity = card.get('rarity', 'unknown')
        pricing = card['pricing']
        
        print(f"🃏 {name} ({rarity})")
        
        # Group pricing by date
        price_by_date = defaultdict(list)
        for p in pricing:
            price_by_date[p['date']].append(p)
        
        for date_key in sorted(price_by_date.keys())[-2:]:  # Last 2 dates
            prices = price_by_date[date_key]
            usd_prices = [p for p in prices if p['currency'] == 'usd']
            
            if usd_prices:
                price_str = ", ".join(f"${p['price_value']} ({p['price_type']})" for p in usd_prices)
                print(f"   {date_key}: {price_str}")
        print()

print("✅ Analysis functions ready")
# Out:
# ✅ Analysis functions ready

# %% [markdown]
# ## 7. Current Status

# %%
# Run coverage analysis
analyze_pricing_coverage()
# Out:
# 📊 PRICING COVERAGE ANALYSIS
# ========================================
# Total Cards: 110,031
# Cards with Pricing: 99,341
# Coverage: 90.28%
#
# 📅 Recent Pricing by Date:
#    2025-12-13: 320,666 records
#    2025-12-12: 767 records
#
# 💰 Price Types:
#    usd: 80,819 records
#    eur: 77,013 records
#    usd_foil: 55,148 records
#    tix: 54,222 records
#    eur_foil: 53,013 records
#    usd_etched: 1,218 records

# %% [markdown]
# ## 8. Ready for Production
#
# The pipeline is now clean and production-ready. Key improvements:
#
# 1. **Bulk API Usage**: 75 cards per request (much more efficient)
# 2. **Comprehensive Pricing**: Captures USD, EUR, MTGO, and all foil variants
# 3. **Smart Batching**: Processes cards in manageable chunks
# 4. **Duplicate Prevention**: Skips existing records automatically
# 5. **Error Handling**: Robust logging and error recovery
# 6. **Scalable**: Can handle full database (110K+ cards)
#
# To run the full pipeline:
# ```python
# # For today's pricing
# result = run_daily_pricing_pipeline()
#
# # For specific date
# result = run_daily_pricing_pipeline(target_date='2025-12-13')
# ```
